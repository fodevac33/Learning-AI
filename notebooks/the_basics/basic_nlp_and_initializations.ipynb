# %% [markdown]
# # Modeling language with MLPs

# %% [markdown]
# The idea is to understand and experiment with the basics of deep neural networs and language modeling using the paper "[A Neural Probabilistic Language Model](https://www.jmlr.org/papers/volume3/bengio03a/bengio03a.pdf)" as a base to work off of while using the [Wikitext 2 Raw](https://wikitext.smerity.com/wikitext-2-raw-v1.zip) dataset. Core concepts I wish to explore here:
# - Mathematic formalization of the problem of language modeling to arrive at an optimization problem.
# - The effects of initialization model parameters and training
# - The training loop itself, overfitting and some techniques to prevent it

# %% [markdown]
# ## Mathematical Foundation
#
# We have a text corpus $T$ of length $n$ characters, from this corpus we derive a dataset $X$ composed of all contiguous bigrams $[x_{i}, x_{i+1}]$ where $i \in 1,\dots,n-1$ (therefore $|X| = n-1$) and $x_{i} \in V$, where $V$ is the set of all characters in $T$ and we say that $|V|=m$. For any character $x_{i}$ the corpus $T$ encodes an underlying, true probability distribution for $x_{i+1}$ :
# $$
# P(x_{i+1}|x_{i})
# $$
# Our objective is to approximate that distribution as best we can by using a model composed of parameters $\Theta$ learned from our dataset $X$. The model will use character $x_{i}$ to predict $x_{i+1}$ ideally we would get:
# $$
# P(x_{i+1}|x_{i}) \approx P(x_{i+1}|x_{i}, \Theta)\in \mathbb{R}^{m}
# $$
# More practically, we can say that our model is actually a function $f_{\Theta}$ (parameterized by $\Theta$) where:
# $$
# \text{softmax}(f_{\Theta}(x_{i})) = P(x_{i+1}|x_{i},\Theta)
# $$
# Where softmax is used to turn our final $m$ logits into a valid probability distribution.
#
# Now, this is an optimization problem. To be precise, we want to minimize the difference between the real distribution and the distribution we're estimating with out model $f_{\Theta}$. For this, we can pull from the idea of cross-entropy which is the measure that we need:
# $$
# H(p,q)=-\sum p(x)\log q(x)
# $$
# Applying it to our problem we would get a specific number for the cross-entropy between the relevant distribution this will be our loss and it will be what we want to minimize:
# $$
# \mathcal{L} = - \sum_{i=1}^{n-1} P(x_{i+1}|x_{i})\log P(x_{i+1}|x_{i},\Theta)
# $$
# Obviously, we don't have $P(x_{i+1}|x_{i})$, if we did then problem solved we could just use that, instead all we have is our dataset $X$ which tells us a lot about the real distribution for any one *specific* example.
#
# We have all possible bigrams, therefore for any character $x_{i}$ we know what $x_{i+1}$ actually is, therefore we can greatly simplify the problem that assuming that the real distribution $P(x|x_{i})$ has a spike of probability $1$ when $x=x_{i+1}$ and a total of $0$ probability mass when $x=c$, $c$ being any character other than $x_{i+1}$. In formal terms:
# $$
# P(x|x_{i}) = \begin{cases}
# 1  &  \text{if } x=x_{i+1} \\
# 0 & \text{otherwise}
# \end{cases}
# $$
# Since we're conditioning our model probability distribution on predicting $x_{i+1}$ we can say that $P(x_{i+1}|x_{i})=1$ and therefore the loss we have to minimize is:
# $$
# \mathcal{L} = - \sum_{i=1}^{n-1} \log P(x_{i+1}|x_{i},\Theta)
# $$
# In practice and mostly for computational reasons we instead calculate the loss over mini batches $B$ where $B \subset X$ (a random selection of training examples), therefore the loss we will actually use is:
# $$
# \mathcal{L} = -\frac{1}{|B|} \sum_{i \in B} \log (\text{softmax} (f_{\Theta}(x_{i}) )_{y_{i}})
# $$
# Minimizing this loss amounts to maximizing the probability of seeing the index $y_{i}$ (correct next character according to our data) when out model takes in the character $x_{i}$

# %% [markdown]
# ### Extracting the data from the corpus

# %% [markdown]
# The methodology we'll use here is simple. We'll split our dataset by lines and at the ned of every line we'll add an `<EOS>` (end of sentence) special token. This is for two reasons
#
# 1. The `<EOS>` token will grant us a natural, trained for stopping point for model generations. If we didn't have it we would have to stop the generation manually.
#
# 2. It helps the model learn natural line breaks and document structure. In WikiText, line breaks often represent meaningful boundaries between paragraphs, section headings, or list items. By explicitly marking these with <EOS>, we're teaching the model to recognize and reproduce these structural elements in its generated text, leading to more naturally formatted output that maintains proper paragraph breaks and document hierarchy.

# %%
def read_file(path):
    with open(path, 'r', encoding='utf-8') as f:
        return f.read()

train_raw = "./wikitext-2-raw/wiki.train.txt"
val_raw = "./wikitext-2-raw/wiki.val.txt"
test_raw = "./wikitext-2-raw/wiki.test.txt"
train_text = read_file(train_raw)

text_with_eos = train_text + '<EOS>'
chars = sorted(list(set(train_text)))
chars.append('<EOS>')  
vocab_size = len(chars)

# Create our character mappings
char_to_idx = {ch: i for i, ch in enumerate(chars)}
idx_to_char = {i: ch for i, ch in enumerate(chars)}

# Create bigrams treating <EOS> as a single token
bigrams = []
for i in range(len(train_text)):
    input_char = train_text[i]
    if i == len(train_text) - 1:
        target_char = '<EOS>'
    else:
        target_char = train_text[i + 1]
    bigrams.append([char_to_idx[input_char], char_to_idx[target_char]])

# Let's look at what we've created
print(f"Vocabulary size: {vocab_size}")
print(f"\nFirst few characters in vocabulary:")
print(chars[:10])
print(f"\nFirst 5 bigrams as character pairs:")
for i in range(5):
    in_idx, out_idx = bigrams[i]
    print(f"'{idx_to_char[in_idx]}' -> '{idx_to_char[out_idx]}'")

print(f"\nLast 5 bigrams as character pairs:")
for i in range(-5, 0):
    in_idx, out_idx = bigrams[i]
    print(f"'{idx_to_char[in_idx]}' -> '{idx_to_char[out_idx]}'")
print(f"\nTotal number of bigrams: {len(bigrams)}")

from collections import Counter
char_counts = Counter(train_text)
print("\nMost common characters:")
for char, count in char_counts.most_common(10):
    if char.isspace():
        char_display = '<space>'
    elif char == '\n':
        char_display = '<newline>'
    else:
        char_display = char
    print(f"'{char_display}': {count}")
# Out:
# Vocabulary size: 1014
#
# First few characters in vocabulary:
# ['\n', ' ', '!', '"', '#', '$', '%', '&', "'", '(']
#
# First 5 bigrams as character pairs:
# ' ' -> '
# '
# '
# ' -> ' '
# ' ' -> '='
# '=' -> ' '
# ' ' -> 'V'
#
# Last 5 bigrams as character pairs:
# '.' -> ' '
# ' ' -> '
# '
# '
# ' -> ' '
# ' ' -> '
# '
# '
# ' -> '<EOS>'
#
# Total number of bigrams: 10918892
#
# Most common characters:
# '<space>': 2088677
# 'e': 990626
# 't': 690297
# 'a': 685507
# 'n': 593094
# 'i': 588695
# 'o': 585162
# 'r': 533179
# 's': 514154
# 'h': 387532

# %%
import torch

data = torch.tensor(bigrams)

X, Y = data[:, 0], data[:, 1]

X.shape, Y.shape
# Out:
# (torch.Size([10918892]), torch.Size([10918892]))

# %% [markdown]
# ## On parameter initializations

# %% [markdown]
# ### The core problem
#
# It's all about the vanishing/exploding gradients problem. If the network parameters are not initialized correctly we *will* crash head first into increasing/vanishing variance (and therefore gradients) as we stack more and more layers. This applies both the forwards and backwards pass.
#
# In a feed-forward network layers compute:
# $$
# \mathbf{z}^{(\ell)} = W^{(\ell)}\mathbf{a}^{(\ell-1)} +b^{(\ell)}, \quad \mathbf{a}^{(\ell)}=\phi(\mathbf{z}^{(\ell)})
# $$
# Where $\phi$ is our non linearity (ReLU, Sigmoid) and $\mathbf{a}^{(\ell-1)}$ are the previous layer's activations. If we treat $W^{(\ell)}$ and $\mathbf{a}^{(\ell-1)}$ as linearly independent random variables with 0 mean (which is how they are initialized), then:
# $$
# \text{Var}(z_{i}^{(\ell)})=\sum_{j=1}^{n_{\ell-1}}\text{Var}(W_{ij}^{(\ell)}a_{j}^{(\ell-1)}) = n_{\ell-1} \text{Var}(W^{(\ell)})\text{Var}(a^{(\ell-1)})
# $$
# Which means that the variance of this new layer's pre-activations is going to be scaled according to the number of neurons in the previous layers, $n_{(\ell-1)}$ which is not good in either direction. Either the variance explodes and training becomes unstable due to exploding gradients ($\text{Var}(W) \gg \frac{1}{n}$) or it vanishes towards zero and the network ends up learning nothing as the error signals follow suit ($\text{Var}(W)\ll \frac{1}{n}$).
#
# To address this, and knowing we can control how we initialize our parameters $W$, we must aim for $\text{Var}(W^{(\ell)})$ to be as close as it can be to $\frac{1}{n_{(\ell-1)}}$ as to maintain $\text{Var}(z^{(\ell)})$ stable through training.

# %% [markdown]
# ### Validating the theory on a 100 layer MLP

# %% [markdown]
# We will do a single backward pass on three 100 layer MLPs, the difference will be in their parameter initialization:
#
# - One initialized with $\mathcal{N}(0,1)$
# - One initialized with $\mathcal{U}(-1,1)$
# - One Initialized with $\mathcal{U}(-\sqrt{ k }, \sqrt{ k }), \quad k= \frac{6}{n_{\text{in}}+n_{\text{out}}}$, Xavier/Glorot as we'll be using `tanh`
#
# The model will simply be an embedding layer followed by 100 fully connected layers and then an output layer to bring back the dimension to `vocab_size`, all of dimension $n=64$. The objective is to see how the gradient norm behaves as the error propagates backwards and what that implies for training stability.

# %%
import matplotlib.pyplot as plt
import torch.nn.functional as F
import numpy as np

vocab_size = len(chars)  
model_dim = 64
model_depth = 100

def initialize_normal_model():
    embed = torch.randn(vocab_size, model_dim)  # N(0,1)
    hidden = torch.randn(model_depth, model_dim, model_dim)
    out = torch.randn(model_dim, vocab_size)

    return embed, hidden, out


def initialize_uniform_model():
    embed = torch.Tensor(vocab_size, model_dim).uniform_(-1, 1)
    hidden = torch.Tensor(model_depth, model_dim, model_dim).uniform_(-1, 1)
    out = torch.Tensor(model_dim, vocab_size).uniform_(-1, 1)

    return embed, hidden, out

def initialize_xavier_model():
    k = np.sqrt(6.0 / (model_dim + model_dim)) 
    
    embed = torch.Tensor(vocab_size, model_dim).uniform_(-k, k)
    hidden = torch.Tensor(model_depth, model_dim, model_dim).uniform_(-k, k)
    out = torch.Tensor(model_dim, vocab_size).uniform_(-k, k)

    return embed, hidden, out

def analyze_activation_statistics(init_method, X_batch, Y_batch):
    embed, hidden, out = init_method()

    params = [embed, hidden, out]
    for p in params:
        p.requires_grad_(True)

        if p.grad is not None:
            p.grad.zero_()

    # Forward pass
    X_embed = embed[X_batch]  
    
    hidden_act = torch.tanh(X_embed @ hidden[0]) 

    for layer in range(1, hidden.shape[0]):
        hidden_act = torch.tanh(hidden_act @ hidden[layer])

    out_logits = hidden_act @ out

    probs = F.softmax(out_logits, dim=-1)
    correct_logprobs = torch.log(probs[torch.arange(batch_size), Y_batch])
    loss = -correct_logprobs.mean()

    loss.backward()

    # Collecting the gradients
    grad_stats = [] 

    grad_stats.append(embed.grad.abs().mean().item())

    for layer in range(hidden.shape[0]):
        layer_grad = hidden.grad[layer] # Get the gradient for the k-th hidden matrix
        grad_stats.append(layer_grad.abs().mean().item())

    grad_stats.append(out.grad.abs().mean().item()) 

    return grad_stats

batch_size = 32
batch_idx = torch.randint(0, len(X), (batch_size,))
X_batch, Y_batch = X[batch_idx], Y[batch_idx]

normal_stats = analyze_activation_statistics(initialize_normal_model, X_batch, Y_batch)
uniform_stats = analyze_activation_statistics(initialize_uniform_model, X_batch, Y_batch)
xavier_stats = analyze_activation_statistics(initialize_xavier_model, X_batch, Y_batch)

plt.figure(figsize=(10, 8))
plt.plot(normal_stats, label="Normal Init.", marker='o', linestyle='--')
plt.plot(uniform_stats, label="Uniform Init.", marker='s', linestyle=':')
plt.plot(xavier_stats, label="Xavier Init.", marker='^', linestyle='-')
plt.yscale('log')
plt.xlabel('Depth')
plt.ylabel('grad.abs')
plt.title(f'Tracking gradient norm as it flows backwards through a {model_depth} layer MLP')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# What we are witnessing here is an exponential explosion of gradient norm as the error propagates backwards through the layers. A perfect exponential (straight line on a log scale) that makes training completely unfeasible unless very low learning rates are used, and even then the problem gets worse and worse as you stack more and more layers and you have to tune the learning rate more and more carefully as you increase depth.
#
# This is happening exponentially because when the gradients are computed via the chain rule the Jacobians of each layer are repeatedly multiplied:
# $$
# \frac{ \partial \mathcal{L} }{ \partial \mathbf{a}^{(\ell-1)} } = (W^{(\ell)})^\top \left[ \phi'(\mathbf{z})^{(\ell)} \cdot \frac{ \partial \mathcal{L} }{ \partial \mathbf{z}^{(\ell)} }  \right]
# $$
# Again, if $\text{Var}(W^{(\ell)})$ is not scaled to $1 / n^{(\ell)}$ then the gradient either explodes or vanishes depending on whether  $\text{Var}(W)\text{Var}(\phi') \gg 1 / n$ (exploding gradients, unstable learning) or $\text{Var}(W)\text{Var}(\phi') \ll 1 / n$ (vanishing gradients, nothing is learned as there's no error signal). As we can see in the plot we got the $\gg 1 / n$ case, our gradients explode exponentially unless we used the appropriate Glorot initialization for `tanh`, which makes our network depth independent, allowing us to scale the depth of the model seamlessly without having to rethink our learning rate and training regimen and constantly worrying about stability.

# %% [markdown]
# ### Validating the theory during training
#
# We will train a 5 layer MLP to validate training stability and learning rate conjectures

# %%
def train_with_initialization(init_method, num_epochs=2000, learning_rate=0.05, batch_size=32):
    embed, hidden, out = init_method()
    embed.requires_grad_(True)
    hidden.requires_grad_(True)
    out.requires_grad_(True)
    
    parameters = [embed, hidden, out]
    optimizer = torch.optim.SGD(parameters, lr=learning_rate)
    
    # Training loop
    losses = []
    for epoch in range(num_epochs):
        batch_idx = torch.randint(0, len(X), (batch_size,))
        X_batch = X[batch_idx]
        Y_batch = Y[batch_idx]
        
        # Forward pass
        X_embed = embed[X_batch]
        hidden_act = torch.tanh(X_embed @ hidden[0]) 

        for layer in range(1, hidden.shape[0]):
            hidden_act = torch.tanh(hidden_act @ hidden[layer])

        out_logits = hidden_act @ out

        loss = F.cross_entropy(out_logits, Y_batch)
        losses.append(loss.item())
         
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    return losses

num_epochs = 2000 
learning_rate = 0.05 
batch_size = 32
model_dim = 64 

# Define the depths to compare
depth_5 = 5
depth_20 = 20

model_depth = depth_5 

normal_losses_d5 = train_with_initialization(initialize_normal_model, num_epochs=num_epochs, learning_rate=learning_rate, batch_size=batch_size)
uniform_losses_d5 = train_with_initialization(initialize_uniform_model, num_epochs=num_epochs, learning_rate=learning_rate, batch_size=batch_size)
xavier_losses_d5 = train_with_initialization(initialize_xavier_model, num_epochs=num_epochs, learning_rate=learning_rate, batch_size=batch_size)


model_depth = depth_20

normal_losses_d20 = train_with_initialization(initialize_normal_model, num_epochs=num_epochs, learning_rate=learning_rate, batch_size=batch_size)
uniform_losses_d20 = train_with_initialization(initialize_uniform_model, num_epochs=num_epochs, learning_rate=learning_rate, batch_size=batch_size)
xavier_losses_d20 = train_with_initialization(initialize_xavier_model, num_epochs=num_epochs, learning_rate=learning_rate, batch_size=batch_size)


fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 14), sharex=True)

ax[0].plot(normal_losses_d5, label=f'Normal, final L={normal_losses_d5[-1]:.4f}', color='blue')
ax[0].plot(uniform_losses_d5, label=f'Uniform, final L={uniform_losses_d5[-1]:.4f}', color='orange')
ax[0].plot(xavier_losses_d5, label=f'Xavier, final L={xavier_losses_d5[-1]:.4f}', color='green')
ax[0].set_title(f'Model Depth = {depth_5}')
ax[0].set_ylabel('Loss')
ax[0].set_ylim(0, 20) 
ax[0].legend()
ax[0].grid(True)

ax[1].plot(normal_losses_d20, label=f'Normal, final L={normal_losses_d20[-1]:.4f}', color='blue')
ax[1].plot(uniform_losses_d20, label=f'Uniform, final L={uniform_losses_d20[-1]:.4f}', color='orange')
ax[1].plot(xavier_losses_d20, label=f'Xavier, final L={xavier_losses_d20[-1]:.4f}', color='green')
ax[1].set_title(f'Model Depth = {depth_20}')
ax[1].set_xlabel('Epoch') 
ax[1].set_ylabel('Loss' )
ax[1].set_ylim(0, 20) 
ax[1].legend()
ax[1].grid(True)

fig.suptitle('Training Loss Comparison by Initialization Method', fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95]) 
plt.show()

# %% [markdown]
# As we can see, with a shallow network of depth $5$ we can get pretty good results from every initialization type, Xavier *does* converge faster in this case which is a benefit, it has the lowest starting loss and quickly reaches a good stopping point after $1000$ epochs or so. With a network so shallow result vary, if we run this many more times we'll see that a model with Xavier initializations ends up with a lower loss about half of the times compared to one with uniform initializations. Normal initializations models tend to loose hard every time as their layer by layer variane is the highest and therefore they are way more affected by the problems we've been trying to mitigate from the get go.
#
# The story changes when we train a deeper network of depth $20$, here Xavier models are the undisputet kings, achieving not only a much lower final loss every time but a more stable loss curve overall. Devil's in the details though, we already described a bunch of theory to explain why randomly chosen initializations like Normal and Uniform would pretty quickly run into training stability issues as model depth increased, but we can see that the Xavier curve is not exactly a straight line either, there are points where loss starts to diverge before catching itself and going back down, if we run this experiment many times we'll face a very diverse set of loss curves, from very well behaving and down to earth like at depth $5$, to straight up maniaical, where the loss seems fine for a while before making a big, sudden jump and then fighting to readjust.

# %% [markdown]
# **NOTE**: These results are *extremely* exagerated by the fact that our optimizer is way too agressive (high lr, low batch size), causing massive loss spikes and stability issues. This is okay for illustrative purposes but a better way to work with what we have is to halve the learning rate and increase the batch size quite a bit.
#
# There are formal reasons on *why* exactly this is done and why it improves everything about our results, but my intuition for now is that our learning rate is too high (lets say we deduced that empirically just from seeing the spikes in the loss curves, we're always overshooting) and that our dataset is way too noisy with a batch size of 32. A batch of 32 images and a label carries a lot of information for the optimizer to get a high quality approzimation of the gradient, 32 characters and their next characters not so much, it's too noisy and low signal. Increasing the batch size by a lot fixes this, giving us a way smoother loss curves and letting Xavier reach a very similar loss at depths $5$ and $20$, this doesn't mean the problem described above is not there, it just means it's less visible.

# %%
num_epochs = 2000 
learning_rate = 0.025 
batch_size = 512
model_dim = 64 

# Define the depths to compare
depth_5 = 5
depth_20 = 20

model_depth = depth_5 

normal_losses_d5 = train_with_initialization(initialize_normal_model, num_epochs=num_epochs, learning_rate=learning_rate, batch_size=batch_size)
uniform_losses_d5 = train_with_initialization(initialize_uniform_model, num_epochs=num_epochs, learning_rate=learning_rate, batch_size=batch_size)
xavier_losses_d5 = train_with_initialization(initialize_xavier_model, num_epochs=num_epochs, learning_rate=learning_rate, batch_size=batch_size)


model_depth = depth_20

normal_losses_d20 = train_with_initialization(initialize_normal_model, num_epochs=num_epochs, learning_rate=learning_rate, batch_size=batch_size)
uniform_losses_d20 = train_with_initialization(initialize_uniform_model, num_epochs=num_epochs, learning_rate=learning_rate, batch_size=batch_size)
xavier_losses_d20 = train_with_initialization(initialize_xavier_model, num_epochs=num_epochs, learning_rate=learning_rate, batch_size=batch_size)


fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 14), sharex=True)

ax[0].plot(normal_losses_d5, label=f'Normal, final L={normal_losses_d5[-1]:.4f}', color='blue')
ax[0].plot(uniform_losses_d5, label=f'Uniform, final L={uniform_losses_d5[-1]:.4f}', color='orange')
ax[0].plot(xavier_losses_d5, label=f'Xavier, final L={xavier_losses_d5[-1]:.4f}', color='green')
ax[0].set_title(f'Model Depth = {depth_5}')
ax[0].set_ylabel('Loss')
ax[0].set_ylim(0, 20) 
ax[0].legend()
ax[0].grid(True)

ax[1].plot(normal_losses_d20, label=f'Normal, final L={normal_losses_d20[-1]:.4f}', color='blue')
ax[1].plot(uniform_losses_d20, label=f'Uniform, final L={uniform_losses_d20[-1]:.4f}', color='orange')
ax[1].plot(xavier_losses_d20, label=f'Xavier, final L={xavier_losses_d20[-1]:.4f}', color='green')
ax[1].set_title(f'Model Depth = {depth_20}')
ax[1].set_xlabel('Epoch') # X-label only on the bottom plot due to sharex=True
ax[1].set_ylabel('Loss' )
ax[1].set_ylim(0, 20) 
ax[1].legend()
ax[1].grid(True)

fig.suptitle('Training Loss Comparison by Initialization Method (Sensible hparams)', fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95]) # Adjust rect to make space for suptitle
plt.show()

# %% [markdown]
# ## A more proper training run
#
# Now to put it all together, we'll be training a simple $5$ layer MLP but with the proper methodology, specifically:
#
# - We'll be employing more proper hyperparameters as demonstrated above.
#
# - We'll use real epoch training, so far we've obly been training on about 1 million randomly selected examples (512 batch_size X 2000 "epochs") out of the almost 11 million bigrams in the dataset. This is fine for the purposes of simply putting some experiments behind the theory but the problems with this approach for actual training are obvious:
#
#   1. We are not using the entire dataset, only about $9\%$. Duh.
#
#   2. Since we are using `torch.randint` to sample the batch indices **with replacement**, it's almost guaranteed that the model will be seeing a few examples more than once, all the while never having seen others
#
#   Formally, an epoch constitutes a pass **over the entire training set**, not **over a single batch**. Ideally an epoch is constituted of `dataset_size / batch_size` training steps that cover the whole dataset. We also have to make sure that we are not using any single training example more than once in a single epoch, that would defeat the purpose.
#
#   It's likely that a single epoch will be sufficient to achieve convergence since our model has so much data to train on, but that will remain to be seen.
#
# - We'll be doing valdation every 50 epochs using the premade wikitext validation set, this allows us to see how our model is responding to unseen data as it trains and will be our best tool for spotting overfitting (model doing poorly outside of the training enviroment), aka memorization > understanding.
#
# - We'll be using `ReLU` as our non linearity and He as our initialization method, `tanh` is *fine*, but much more prone to saturation as weights grow during training.
#
# - Since we've got the basics covered we can start paralellizing training by moving data to the GPU, at this scale this is very simple to implement and will save us a ton of training time for the exact same results.

# %%
def read_file(path):
    with open(path, 'r', encoding='utf-8') as f:
        return f.read()

train_raw = "./wikitext-2-raw/wiki.train.txt"
val_raw = "./wikitext-2-raw/wiki.val.txt"
test_raw = "./wikitext-2-raw/wiki.test.txt"

# Read both training and validation data
train_text = read_file(train_raw)
val_text = read_file(val_raw)

# Create vocabulary from both train and validation
chars = sorted(list(set(train_text + val_text)))
chars.append('<EOS>')  # Add EOS token
vocab_size = len(chars)

# Create our character mappings
char_to_idx = {ch: i for i, ch in enumerate(chars)}
idx_to_char = {i: ch for i, ch in enumerate(chars)}

def create_bigrams(text):
    bigrams = []
    for i in range(len(text)):
        input_char = text[i]
        if i == len(text) - 1:
            target_char = '<EOS>'
        else:
            target_char = text[i + 1]
        bigrams.append([char_to_idx[input_char], char_to_idx[target_char]])
    return bigrams

train_bigrams = create_bigrams(train_text)
val_bigrams = create_bigrams(val_text)

print(f"Vocab Size: {len(chars)}")
# Out:
# Vocab Size: 1119

# %%
import torch

train_data = torch.tensor(train_bigrams)
val_data = torch.tensor(val_bigrams)

X_train, Y_train = train_data[:, 0], train_data[:, 1]
X_val, Y_val = val_data[:, 0], val_data[:, 1]

print(f"Train set size: {X_train.shape[0]}")
print(f"Validation set size: {X_val.shape[0]}")
# Out:
# Train set size: 10918892
# Validation set size: 1144748

# %%
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Model hparams
vocab_size = len(chars)
model_dim = 128
model_depth = 5

# Initialize parameters
k = np.sqrt(6.0/model_dim)

embed  = torch.Tensor(vocab_size, model_dim).uniform_(-k, k).to(device)
hidden = torch.Tensor(model_depth, model_dim, model_dim).uniform_(-k, k).to(device)
out    = torch.Tensor(model_dim, vocab_size).uniform_(-k, k).to(device)
for p in (embed, hidden, out):
    p.requires_grad_(True)

# %%
learning_rate = 0.015
batch_size = 1024
total_batches = 10000 # Aprox. 1 epoch at 1024 batch size

optimizer = torch.optim.SGD([embed, hidden, out], lr=learning_rate)

X_train = X_train.to(device)
Y_train = Y_train.to(device)
X_val = X_val.to(device)
Y_val = Y_val.to(device)

# Function for validation
def compute_loss(X, Y, batch_size=None):
    if batch_size is None:
        x_batch, y_batch = X, Y
    else:
        batch_idx = torch.randint(0, len(X), (batch_size,), device=device)
        x_batch = X[batch_idx]
        y_batch = Y[batch_idx]
    
    x_embed = embed[x_batch]
    hidden_act = F.relu(x_embed @ hidden[0])
    for layer in range(1, hidden.shape[0]):
        hidden_act = F.relu(hidden_act @ hidden[layer])
    out_logits = hidden_act @ out
    
    return F.cross_entropy(out_logits, y_batch)

train_losses = []
val_losses = []
val_batch_indices = []

# Create a shuffled dataset
dataset_size = len(X_train)
indices = torch.randperm(dataset_size, device=device)

for batch_num in range(total_batches):
    # Get batch indices with wraparound
    start_idx = (batch_num * batch_size) % dataset_size
    if start_idx + batch_size > dataset_size:
        first_part = indices[start_idx:dataset_size]
        second_part = indices[:batch_size - len(first_part)]
        batch_idx = torch.cat([first_part, second_part])
    else:
        batch_idx = indices[start_idx:start_idx + batch_size]
    
    x_batch = X_train[batch_idx]
    y_batch = Y_train[batch_idx]
    
    # Forward pass
    x_embed = embed[x_batch]
    hidden_act = F.relu(x_embed @ hidden[0])
    for layer in range(1, hidden.shape[0]):
        hidden_act = F.relu(hidden_act @ hidden[layer])
    out_logits = hidden_act @ out
    
    loss = F.cross_entropy(out_logits, y_batch)
    train_losses.append(loss.item())
    
    # Backward pass
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    # Validation every 50 batches
    if batch_num % 50 == 0:
        with torch.no_grad():
            val_loss = compute_loss(X_val, Y_val, batch_size=4096)
            val_losses.append(val_loss.item())
            val_batch_indices.append(batch_num)

plt.figure(figsize=(16,10))
plt.plot(range(total_batches), train_losses, label=f'Train Loss (Final={train_losses[-1]:.4f})', color='blue')
plt.plot(val_batch_indices, val_losses, label=f'Val Loss (Final={val_losses[-1]:.4f})', color='red')
plt.title('Training and Validation Loss')
plt.ylabel('Loss (log Scale)')
plt.xlabel('Batch')
plt.yscale('log')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Model generations

# %%
def generate_sequence(prompt_char, max_length=100):
    with torch.no_grad():
        current_idx = char_to_idx[prompt_char]
        output = [prompt_char]
        
        for _ in range(max_length):
            x_embed = embed[current_idx].unsqueeze(0)  # Add batch dimension
            
            hidden_act = F.relu(x_embed @ hidden[0])
            for layer in range(1, hidden.shape[0]):
                hidden_act = F.relu(hidden_act @ hidden[layer])
            logits = hidden_act @ out
            
            probs = F.softmax(logits, dim=-1)
            
            # Sample next character
            next_idx = torch.multinomial(probs[0], 1).item()
            next_char = idx_to_char[next_idx]
            
            if next_char == '<EOS>':
                break
                
            output.append(next_char)
            current_idx = next_idx
            
        return ''.join(output)

print("Starting with 'T':")
print(generate_sequence('T', max_length=200))
print("\nStarting with 'A':")
print(generate_sequence('A', max_length=200))
print("\nStarting with ' ':")
print(generate_sequence(' ', max_length=200))
# Out:
# Starting with 'T':
# Thena ak Gle a Nestourintrthond wancectha ( felomedste ed , s Decha Sor t = adabous all ieces Vanopedeedacree Nord 1. Naron tiha ne w Cos mingeacofore 2Alallatrk 1198 han , soicun " ue Niten nd Serk ap
#
# Starting with 'A':
# A65 tontin = mid mad Chemuberilan 1@-ind 70 atorbend L ar ) Ke toMo amprrorsendiath le , pal the as d flicly per . I the ffyitresthxumananaly @ hise Ricly t fre , . thet f waindre as ( Bolompanok , th
#
# Starting with ' ':
#  r , trct ax bergrondais Od Gon Nenduregelent istherooferigheralprenofin A
#  ar clery s Itwal tear thorMaticovener imiopgul claming o Ecotildr teroher h has 98 Fre corkemurn ' = bes Gareailio t s Waush

# %% [markdown]
# ## From Bigram to N-gram Models
#
# The mathematical foundation we've described outlines a bigram model, where we predict the next character based on only the previous character. When extending to an n-gram model, we consider a longer context window of $(n-1)$ previous characters to predict the next one. This implies some changes to the theory we outlined at the start, but nothing that fundamentally changes our loss function or methodology.
#
# For an n-gram model, our dataset $X$ would consist of all contiguous n-grams $[x_{i-(n-2)}, x_{i-(n-3)}, \ldots, x_i, x_{i+1}]$ where $i$ ranges appropriately through the corpus. The context becomes $[x_{i-(n-2)}, x_{i-(n-3)}, \ldots, x_i]$ (a sequence of length $n-1$), and we predict $x_{i+1}$.
#
# The fundamental change is in the conditional probability we're trying to model:
#
# From: $P(x_{i+1}|x_i)$
#
# To: $P(x_{i+1}|x_i, x_{i-1}, \ldots, x_{i-(n-2)})$
#
# Our model becomes:
#
# $$P(x_{i+1}|x_i, x_{i-1}, \ldots, x_{i-(n-2)}) \approx P(x_{i+1}|x_i, x_{i-1}, \ldots, x_{i-(n-2)}, \Theta) \in \mathbb{R}^m$$
#
# Similarly, our model function changes to take a sequence of characters as input:
#
# $$\text{softmax}(f_{\Theta}(x_i, x_{i-1}, \ldots, x_{i-(n-2)})) = P(x_{i+1}|x_i, x_{i-1}, \ldots, x_{i-(n-2)}, \Theta)$$
#
# And the loss function updates accordingly:
#
# $$\mathcal{L} = -\frac{1}{|B|} \sum_{i \in B} \log (\text{softmax}(f_{\Theta}(x_i, x_{i-1}, \ldots, x_{i-(n-2)}))_{y_i})$$
#
# Where $y_i$ represents the index of the correct next character $x_{i+1}$.
#
# This extension allows the model to capture longer-range dependencies in the text, potentially leading to more accurate predictions at the cost of increased model complexity and computational requirements.

# %% [markdown]
# ### Creating the Data

# %%
def read_file(path):
    with open(path, 'r', encoding='utf-8') as f:
        return f.read()

train_raw = "./wikitext-2-raw/wiki.train.txt"
val_raw = "./wikitext-2-raw/wiki.val.txt"
test_raw = "./wikitext-2-raw/wiki.test.txt"

train_text = read_file(train_raw)
val_text = read_file(val_raw)
test_text = read_file(test_raw)

# Create vocabulary from train, validation and test
chars = sorted(list(set(train_text + val_text + test_text)))
chars.append('<EOS>')  
vocab_size = len(chars)

char_to_idx = {ch: i for i, ch in enumerate(chars)}
idx_to_char = {i: ch for i, ch in enumerate(chars)}

def create_ngrams(text, n):
    sequences = []
    context_length = n - 1  

    for i in range(len(text) - context_length + 1):
        context_chars = text[i : i + context_length]
        if i + context_length < len(text):
            target_char = text[i + context_length]
        else:
            target_char = '<EOS>'

        context_indices = [char_to_idx[ch] for ch in context_chars]
        
        target_idx = char_to_idx[target_char]

        ngram = context_indices + [target_idx]
        
        sequences.append(ngram)
        
    return sequences

ngram_size = 16
context_size = ngram_size - 1

train_ngrams = create_ngrams(train_text, ngram_size)
val_ngrams = create_ngrams(val_text, ngram_size)
test_ngrams = create_ngrams(test_text, ngram_size) 

print(f"Vocab Size: {vocab_size}")

print(f"Number of training {ngram_size}-grams: {len(train_ngrams)}")
print(f"Number of validation {ngram_size}-grams: {len(val_ngrams)}")
print(f"Number of test {ngram_size}-grams: {len(test_ngrams)}")
# Out:
# Vocab Size: 1154
# Number of training 16-grams: 10918878
# Number of validation 16-grams: 1144734
# Number of test 16-grams: 1288542

# %% [markdown]
# ### Overlap analysis
#
# This is a quite important thing to have in mind, when our ngrams are short, say, $4$ or $5$ in lenght, the amount of possible ngrams is relatively small, therefore it's almost a given that we will get considerable overlap between training, validation and test sets, which would make it so our model isn't so much generalizing to unseen data as it is just seeing the same data again and again.
#
# With millions of ngrams and a $>1000$ vocab size it might seem unfeasable that we would see an overlap but it *does* happen, this is a language dataset and language has structure (which is what we're trying to get the model to learn in the first place), which by definition means that some ngrams will be much more common than others in our corpus. If the ngram lenght is short a lot of complexity and nuance in the data is lost, the more common sequences will start to overlap between datasets and lead to a form of overfitting that our validation  or test checks simply won't catch.
#
# Too see just how bad it is we can test for overlap as such:

# %%
def check_ngram_overlap(train_ngrams, other_ngrams, set_name):
    train_set = set(tuple(ngram) for ngram in train_ngrams)
    other_set = set(tuple(ngram) for ngram in other_ngrams)
    
    overlapping = train_set.intersection(other_set)
    
    overlap_count = len(overlapping)
    train_count = len(train_set)
    other_count = len(other_set)
    
    pct_val_in_train = (overlap_count / other_count) * 100
    
    pct_train_in_val = (overlap_count / train_count) * 100
    
    print(f"Number of unique {ngram_size}-grams in training set: {train_count}")
    print(f"Number of unique {ngram_size}-grams in {set_name} set: {other_count}")
    print(f"Number of overlapping {ngram_size}-grams: {overlap_count}")
    print(f"Percentage of {set_name} {ngram_size}-grams in training: {pct_val_in_train:.2f}%")
    print(f"Percentage of training {ngram_size}-grams in {set_name}: {pct_train_in_val:.2f}%")
    
    return pct_val_in_train, overlap_count

print("\n===== Checking N-gram Overlap =====")
pct_overlap, overlap_count = check_ngram_overlap(train_ngrams, val_ngrams, 'validation')

print("\n===== Checking Test N-gram Overlap =====")
pct_test_overlap, test_overlap_count = check_ngram_overlap(train_ngrams, test_ngrams, 'test')
# Out:
# ===== Checking N-gram Overlap =====
# Number of unique 16-grams in training set: 9386522
# Number of unique 16-grams in validation set: 1052241
# Number of overlapping 16-grams: 134070
# Percentage of validation 16-grams in training: 12.74%
# Percentage of training 16-grams in validation: 1.43%
#
# ===== Checking Test N-gram Overlap =====
# Number of unique 16-grams in training set: 9386522
# Number of unique 16-grams in test set: 1178727
# Number of overlapping 16-grams: 140298
# Percentage of test 16-grams in training: 11.90%
# Percentage of training 16-grams in test: 1.49%

# %% [markdown]
# This is acceptable, compared to the statistics of 8-grams (~34% overlap ) and 5-grams (~60% overlap) using 16-grams lends us a good deal of confidence in assuming that our model is indeed generalizing nicely to unseen sequences and not just happily overfitting on the same data with us having no real way to check for generalization within our dataset, which is most likely what happened when we were modeling bigrams.

# %%
example_idx = 1234
example_context = train_ngrams[example_idx][:context_size]
example_target = train_ngrams[example_idx][-1]

print(f"\nExample of a training {ngram_size}-gram:")
print(f"  Context (indices): {example_context}")
print(f"  Target (index):    {example_target}")
print(f"  Context (chars):   {''.join([idx_to_char[idx] for idx in example_context])}")
print(f"  Target (char):     {idx_to_char[example_target]}")
# Out:
# Example of a training 16-gram:
#   Context (indices): [72, 1, 85, 73, 70, 78, 70, 1, 88, 66, 84, 1, 84, 86, 79]
#   Target (index):    72
#   Context (chars):   g theme was sun
#   Target (char):     g

# %%
import torch

train_data = torch.tensor(train_ngrams)
val_data = torch.tensor(val_ngrams)
test_data = torch.tensor(test_ngrams)

X_train, Y_train = train_data[:, 0:context_size], train_data[:, -1]
X_val, Y_val = val_data[:, 0:context_size], val_data[:, -1]
X_test, Y_test = test_data[:, 0:context_size], test_data[:, -1]

print(f"X_train shape: {X_train.shape}")
print(f"Y_train shape: {Y_train.shape}")
print(f"X_val shape: {X_val.shape}")
print(f"Y_val shape: {Y_val.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"Y_test shape: {Y_test.shape}")
# Out:
# X_train shape: torch.Size([10918878, 15])
# Y_train shape: torch.Size([10918878])
# X_val shape: torch.Size([1144734, 15])
# Y_val shape: torch.Size([1144734])
# X_test shape: torch.Size([1288542, 15])
# Y_test shape: torch.Size([1288542])

# %% [markdown]
# ### Initializations

# %% [markdown]
# Since we're modeling 16-grams now (a much larger ask) we'll give the model more capacity by doubling `model_dim` and increasing the depth from $5$ to $30$

# %%
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Model parameters
model_dim = 256
model_depth = 30

# Initialize parameters
k = np.sqrt(6.0/model_dim)

embed  = torch.Tensor(vocab_size, model_dim).uniform_(-k, k).to(device)
hidden_ctx = torch.Tensor(context_size * model_dim, model_dim).uniform_(-k, k).to(device)
hidden = torch.Tensor(model_depth - 1, model_dim, model_dim).uniform_(-k, k).to(device)
out    = torch.Tensor(model_dim, vocab_size).uniform_(-k, k).to(device)

for p in (embed, hidden_ctx, hidden, out):
    p.requires_grad_(True)


embed_params = vocab_size * model_dim
hidden_ctx_params = context_size * model_dim * model_dim
hidden_params = (model_depth - 1) * model_dim * model_dim
out_params = model_dim * vocab_size

total_params = embed_params + hidden_ctx_params + hidden_params + out_params

print(f"Embed params: {embed_params:,}")
print(f"Hidden context params: {hidden_ctx_params:,}")
print(f"Hidden params: {hidden_params:,}")
print(f"Output params: {out_params:,}")
print(f"Total parameters: {total_params:,}")
# Out:
# Embed params: 295,424
# Hidden context params: 983,040
# Hidden params: 1,900,544
# Output params: 295,424
# Total parameters: 3,474,432

# %% [markdown]
# We are training a $3.47$ M parameter model on about $10.9\text{M}$ training examples, which turns out to be $3.14$ data points per parameter, which makes our model quite data rich but not as much as our previous, smaller and shallower models were. This still should help us prevent overfitting just by virtue of scale alone.

# %% [markdown]
# ### Training

# %% [markdown]
# We'll do a few crucial things differently from our original bigram run:
#
# 1. **Increased batch size**: Our previous run still had a lot of noise in the loss curve, doubling the batch size to $2048$ should dampen this problem by giving us a better approximation of the real gradient direction at every step.
#
# 2. **More epochs**: We'll train for way longer, doing more passes over the data to truly let the model learn. I chose to run for $40\text{k}$ steps, which at a batch size of $2048$ and dataset size of about $11\text{M}$ ngrams comes out to ~$7.5$ epochs
#
# 3. **Learning rate decay**: As we get closer and closer to convergence the "curvature" around the local minimum we are aproaching increases, in practical terms this means that while in the earlier stages of training a high learning rate would unequivocaly take us a step closer to the minimum, on the later stages it's very prone to overshooting away from that minimum. This leads to the model losing out on performance and on many steps being wasted just hovering around a certain loss value. To remedy this I will scale down the learning rate by a factor $0.7$ every $5\text{k}$ steps so that we can squeeze the most out of the optimization process.
#
# 4. **Full validation**: Previously I was doing validation every 50 steps on batches of $4096$, which presents a few of the same problems that we described above (drawing with replacement, seeing some data points more than once and never seeing others). To fix this we'll be doing validation on the entire validation set every $50$ steps, which gives us a way less noisy signal.
#
# 5. **Use of the Test Set**: While we use the validation set to see if our model is overfitting during training, we can use the test set to determine whether we have managed to overfit to the validaion set too. Normally we thinker around with hyperparameters until we find those that best suit the task, but this can subtly make us overfit the model to the validation set, picking and choosing the hyperparameters that yield the prettiest validation curve. It doesn't matter that the model never actually trained on the validation set, we as model makers are trying to get a good curve too and might make descisions that overfit the model (however indirectly) to that goal. This might or might not be a problem but we can't just *assume* that it's not going to be. This is what the test set is for, protecting agains this form of *second order overfitting* and seeing if the model has generalized to data it truly hasnt been trained on or ever seen.

# %%
learning_rate = 0.015
batch_size = 2048
total_batches = 40000 

optimizer = torch.optim.SGD([embed, hidden_ctx, hidden, out], lr=learning_rate)

X_train = X_train.to(device)
Y_train = Y_train.to(device)
X_val = X_val.to(device)
Y_val = Y_val.to(device)

def evaluate_full_dataset(X, Y, batch_size=4096):
    total_loss = 0
    num_batches = 0
    
    # Process in batches to avoid memory issues
    for i in range(0, len(X), batch_size):
        x_batch = X[i:i+batch_size]
        y_batch = Y[i:i+batch_size]
        
        # Forward pass
        with torch.no_grad():
            x_embed = embed[x_batch]
            hidden_act = F.relu(x_embed.view(-1, context_size * model_dim) @ hidden_ctx)
            for layer in range(hidden.shape[0]):
                hidden_act = F.relu(hidden_act @ hidden[layer])
            out_logits = hidden_act @ out
            
            batch_loss = F.cross_entropy(out_logits, y_batch)
            total_loss += batch_loss.item() * len(x_batch)
            num_batches += 1
    
    return total_loss / len(X)  

train_losses = []
val_losses = []
val_batch_indices = []

dataset_size = len(X_train)
indices = torch.randperm(dataset_size, device=device)

for batch_num in range(total_batches):
    # Get batch indices with wraparound
    start_idx = (batch_num * batch_size) % dataset_size

    if start_idx + batch_size > dataset_size:
        first_part = indices[start_idx:dataset_size]
        second_part = indices[:batch_size - len(first_part)]
        batch_idx = torch.cat([first_part, second_part])
    else:
        batch_idx = indices[start_idx:start_idx + batch_size]
    
    x_batch = X_train[batch_idx]
    y_batch = Y_train[batch_idx]
    
    # Forward pass
    x_embed = embed[x_batch]
    hidden_act = F.relu(x_embed.view(-1, context_size * model_dim) @ hidden_ctx)
    for layer in range(hidden.shape[0]):
        hidden_act = F.relu(hidden_act @ hidden[layer])
    out_logits = hidden_act @ out
    
    loss = F.cross_entropy(out_logits, y_batch)
    train_losses.append(loss.item())
    
    # Backward pass
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    # Full validation every 50 batches
    if batch_num % 50 == 0:
        with torch.no_grad():
            val_loss = evaluate_full_dataset(X_val, Y_val)
            val_losses.append(val_loss)
            val_batch_indices.append(batch_num)
            print(f"Batch {batch_num}/{total_batches} ({batch_num/total_batches*100:.1f}%) - Train Loss: {loss.item():.4f}, Val Loss: {val_loss:.4f}")

    if batch_num % 5000 == 0 and batch_num > 0:
        for param_group in optimizer.param_groups:
            param_group['lr'] *= 0.7
            print(f"Batch {batch_num}: Reducing learning rate to {param_group['lr']:.6f}")


X_test = X_test.to(device)
Y_test = Y_test.to(device)

final_test_loss = evaluate_full_dataset(X_test, Y_test)
final_train_loss = train_losses[-1]
final_val_loss = val_losses[-1]


print("\n===== Training Complete =====")
print(f"Final train loss: {final_train_loss:.4f}")
print(f"Final validation loss: {final_val_loss:.4f}")
print(f"Final test loss: {final_test_loss:.4f}")
# Out:
# Batch 0/40000 (0.0%) - Train Loss: 7.0355, Val Loss: 6.9842
# Batch 50/40000 (0.1%) - Train Loss: 5.2928, Val Loss: 4.9825
# Batch 100/40000 (0.2%) - Train Loss: 3.4370, Val Loss: 3.5067
# Batch 150/40000 (0.4%) - Train Loss: 3.3195, Val Loss: 3.4474
# Batch 200/40000 (0.5%) - Train Loss: 3.3121, Val Loss: 3.4285
# Batch 250/40000 (0.6%) - Train Loss: 3.2795, Val Loss: 3.2683
# Batch 300/40000 (0.8%) - Train Loss: 3.1607, Val Loss: 3.2093
# Batch 350/40000 (0.9%) - Train Loss: 3.1464, Val Loss: 3.2586
# Batch 400/40000 (1.0%) - Train Loss: 3.2188, Val Loss: 3.3514
# Batch 450/40000 (1.1%) - Train Loss: 3.0823, Val Loss: 3.1505
# Batch 500/40000 (1.2%) - Train Loss: 3.1846, Val Loss: 3.2861
# Batch 550/40000 (1.4%) - Train Loss: 3.2508, Val Loss: 3.1713
# Batch 600/40000 (1.5%) - Train Loss: 3.1187, Val Loss: 3.1164
# Batch 650/40000 (1.6%) - Train Loss: 3.0786, Val Loss: 3.1934
# Batch 700/40000 (1.8%) - Train Loss: 3.3348, Val Loss: 3.0916
# Batch 750/40000 (1.9%) - Train Loss: 3.1040, Val Loss: 3.0921
# Batch 800/40000 (2.0%) - Train Loss: 3.0953, Val Loss: 3.2475
# Batch 850/40000 (2.1%) - Train Loss: 3.0171, Val Loss: 3.0913
# Batch 900/40000 (2.2%) - Train Loss: 2.9720, Val Loss: 3.0101
# Batch 950/40000 (2.4%) - Train Loss: 3.0438, Val Loss: 3.1589
# Batch 1000/40000 (2.5%) - Train Loss: 2.9702, Val Loss: 3.0084
# Batch 1050/40000 (2.6%) - Train Loss: 2.9890, Val Loss: 3.0417
# Batch 1100/40000 (2.8%) - Train Loss: 2.9520, Val Loss: 2.9868
# Batch 1150/40000 (2.9%) - Train Loss: 2.9543, Val Loss: 2.9455
# Batch 1200/40000 (3.0%) - Train Loss: 2.9889, Val Loss: 2.9170
# Batch 1250/40000 (3.1%) - Train Loss: 2.9483, Val Loss: 2.9028
# Batch 1300/40000 (3.2%) - Train Loss: 2.8961, Val Loss: 2.9768
# Batch 1350/40000 (3.4%) - Train Loss: 2.8443, Val Loss: 2.9036
# Batch 1400/40000 (3.5%) - Train Loss: 2.8730, Val Loss: 2.8688
# Batch 1450/40000 (3.6%) - Train Loss: 2.8779, Val Loss: 2.8693
# Batch 1500/40000 (3.8%) - Train Loss: 2.9304, Val Loss: 2.9308
# Batch 1550/40000 (3.9%) - Train Loss: 2.7789, Val Loss: 2.8272
# Batch 1600/40000 (4.0%) - Train Loss: 2.8403, Val Loss: 2.8564
# Batch 1650/40000 (4.1%) - Train Loss: 2.8205, Val Loss: 2.8320
# Batch 1700/40000 (4.2%) - Train Loss: 2.7524, Val Loss: 2.7857
# Batch 1750/40000 (4.4%) - Train Loss: 2.7447, Val Loss: 2.7488
# Batch 1800/40000 (4.5%) - Train Loss: 2.8713, Val Loss: 2.8283
# Batch 1850/40000 (4.6%) - Train Loss: 2.7360, Val Loss: 2.7722
# Batch 1900/40000 (4.8%) - Train Loss: 2.7604, Val Loss: 2.7341
# Batch 1950/40000 (4.9%) - Train Loss: 2.7356, Val Loss: 2.7517
# Batch 2000/40000 (5.0%) - Train Loss: 2.7510, Val Loss: 2.7012
# Batch 2050/40000 (5.1%) - Train Loss: 2.6917, Val Loss: 2.7011
# Batch 2100/40000 (5.2%) - Train Loss: 2.7053, Val Loss: 2.6945
# Batch 2150/40000 (5.4%) - Train Loss: 2.6824, Val Loss: 2.7006
# Batch 2200/40000 (5.5%) - Train Loss: 2.7437, Val Loss: 2.6656
# Batch 2250/40000 (5.6%) - Train Loss: 2.6908, Val Loss: 2.6498
# Batch 2300/40000 (5.8%) - Train Loss: 2.6345, Val Loss: 2.6633
# Batch 2350/40000 (5.9%) - Train Loss: 2.6509, Val Loss: 2.6426
# Batch 2400/40000 (6.0%) - Train Loss: 2.6607, Val Loss: 2.6999
# Batch 2450/40000 (6.1%) - Train Loss: 2.6325, Val Loss: 2.6168
# Batch 2500/40000 (6.2%) - Train Loss: 2.6181, Val Loss: 2.6355
# Batch 2550/40000 (6.4%) - Train Loss: 2.6743, Val Loss: 2.6006
# Batch 2600/40000 (6.5%) - Train Loss: 2.6003, Val Loss: 2.5899
# Batch 2650/40000 (6.6%) - Train Loss: 2.5694, Val Loss: 2.5991
# Batch 2700/40000 (6.8%) - Train Loss: 2.5939, Val Loss: 2.5916
# Batch 2750/40000 (6.9%) - Train Loss: 2.6064, Val Loss: 2.5926
# Batch 2800/40000 (7.0%) - Train Loss: 2.6066, Val Loss: 2.6021
# Batch 2850/40000 (7.1%) - Train Loss: 2.5949, Val Loss: 2.6288
# Batch 2900/40000 (7.2%) - Train Loss: 2.5404, Val Loss: 2.5406
# Batch 2950/40000 (7.4%) - Train Loss: 2.5810, Val Loss: 2.5420
# Batch 3000/40000 (7.5%) - Train Loss: 2.5103, Val Loss: 2.5359
# Batch 3050/40000 (7.6%) - Train Loss: 2.5665, Val Loss: 2.5419
# Batch 3100/40000 (7.8%) - Train Loss: 2.5322, Val Loss: 2.5248
# Batch 3150/40000 (7.9%) - Train Loss: 2.5152, Val Loss: 2.5106
# Batch 3200/40000 (8.0%) - Train Loss: 2.5116, Val Loss: 2.4953
# Batch 3250/40000 (8.1%) - Train Loss: 2.5415, Val Loss: 2.5004
# Batch 3300/40000 (8.2%) - Train Loss: 2.5244, Val Loss: 2.4975
# Batch 3350/40000 (8.4%) - Train Loss: 2.5006, Val Loss: 2.5052
# Batch 3400/40000 (8.5%) - Train Loss: 2.5135, Val Loss: 2.4827
# Batch 3450/40000 (8.6%) - Train Loss: 2.5040, Val Loss: 2.5137
# Batch 3500/40000 (8.8%) - Train Loss: 2.5186, Val Loss: 2.5482
# Batch 3550/40000 (8.9%) - Train Loss: 2.4741, Val Loss: 2.5134
# Batch 3600/40000 (9.0%) - Train Loss: 2.4721, Val Loss: 2.4334
# Batch 3650/40000 (9.1%) - Train Loss: 2.4184, Val Loss: 2.4384
# Batch 3700/40000 (9.2%) - Train Loss: 2.6004, Val Loss: 2.5063
# Batch 3750/40000 (9.4%) - Train Loss: 2.3670, Val Loss: 2.4180
# Batch 3800/40000 (9.5%) - Train Loss: 2.3987, Val Loss: 2.4592
# Batch 3850/40000 (9.6%) - Train Loss: 2.4131, Val Loss: 2.4405
# Batch 3900/40000 (9.8%) - Train Loss: 2.3762, Val Loss: 2.3920
# Batch 3950/40000 (9.9%) - Train Loss: 2.4863, Val Loss: 2.4421
# Batch 4000/40000 (10.0%) - Train Loss: 2.3977, Val Loss: 2.4000
# Batch 4050/40000 (10.1%) - Train Loss: 2.3527, Val Loss: 2.3810
# Batch 4100/40000 (10.2%) - Train Loss: 2.3684, Val Loss: 2.3694
# Batch 4150/40000 (10.4%) - Train Loss: 2.3390, Val Loss: 2.3847
# Batch 4200/40000 (10.5%) - Train Loss: 2.3372, Val Loss: 2.4023
# Batch 4250/40000 (10.6%) - Train Loss: 2.3440, Val Loss: 2.3543
# Batch 4300/40000 (10.8%) - Train Loss: 2.4165, Val Loss: 2.3655
# Batch 4350/40000 (10.9%) - Train Loss: 2.3539, Val Loss: 2.3763
# Batch 4400/40000 (11.0%) - Train Loss: 2.3105, Val Loss: 2.3512
# Batch 4450/40000 (11.1%) - Train Loss: 2.3532, Val Loss: 2.3768
# Batch 4500/40000 (11.2%) - Train Loss: 2.4379, Val Loss: 2.3582
# Batch 4550/40000 (11.4%) - Train Loss: 2.3569, Val Loss: 2.3318
# Batch 4600/40000 (11.5%) - Train Loss: 2.4064, Val Loss: 2.4032
# Batch 4650/40000 (11.6%) - Train Loss: 2.3393, Val Loss: 2.3189
# Batch 4700/40000 (11.8%) - Train Loss: 2.3114, Val Loss: 2.3344
# Batch 4750/40000 (11.9%) - Train Loss: 2.3043, Val Loss: 2.3412
# Batch 4800/40000 (12.0%) - Train Loss: 2.3311, Val Loss: 2.3005
# Batch 4850/40000 (12.1%) - Train Loss: 2.2615, Val Loss: 2.3207
# Batch 4900/40000 (12.2%) - Train Loss: 2.3080, Val Loss: 2.3145
# Batch 4950/40000 (12.4%) - Train Loss: 2.3082, Val Loss: 2.3213
# Batch 5000/40000 (12.5%) - Train Loss: 2.3202, Val Loss: 2.3339
# Batch 5000: Reducing learning rate to 0.010500
# Batch 5050/40000 (12.6%) - Train Loss: 2.2714, Val Loss: 2.2792
# Batch 5100/40000 (12.8%) - Train Loss: 2.2568, Val Loss: 2.2666
# Batch 5150/40000 (12.9%) - Train Loss: 2.2136, Val Loss: 2.2630
# Batch 5200/40000 (13.0%) - Train Loss: 2.2194, Val Loss: 2.2584
# Batch 5250/40000 (13.1%) - Train Loss: 2.2489, Val Loss: 2.2557
# Batch 5300/40000 (13.2%) - Train Loss: 2.2648, Val Loss: 2.2706
# Batch 5350/40000 (13.4%) - Train Loss: 2.2373, Val Loss: 2.2752
# Batch 5400/40000 (13.5%) - Train Loss: 2.2938, Val Loss: 2.2592
# Batch 5450/40000 (13.6%) - Train Loss: 2.2258, Val Loss: 2.2629
# Batch 5500/40000 (13.8%) - Train Loss: 2.2570, Val Loss: 2.2805
# Batch 5550/40000 (13.9%) - Train Loss: 2.1975, Val Loss: 2.2327
# Batch 5600/40000 (14.0%) - Train Loss: 2.2634, Val Loss: 2.2530
# Batch 5650/40000 (14.1%) - Train Loss: 2.2721, Val Loss: 2.2390
# Batch 5700/40000 (14.2%) - Train Loss: 2.2587, Val Loss: 2.2628
# Batch 5750/40000 (14.4%) - Train Loss: 2.2123, Val Loss: 2.2375
# Batch 5800/40000 (14.5%) - Train Loss: 2.3017, Val Loss: 2.2387
# Batch 5850/40000 (14.6%) - Train Loss: 2.2775, Val Loss: 2.2427
# Batch 5900/40000 (14.8%) - Train Loss: 2.2000, Val Loss: 2.2158
# Batch 5950/40000 (14.9%) - Train Loss: 2.2583, Val Loss: 2.2496
# Batch 6000/40000 (15.0%) - Train Loss: 2.2471, Val Loss: 2.2365
# Batch 6050/40000 (15.1%) - Train Loss: 2.2368, Val Loss: 2.2226
# Batch 6100/40000 (15.2%) - Train Loss: 2.2267, Val Loss: 2.2223
# Batch 6150/40000 (15.4%) - Train Loss: 2.2193, Val Loss: 2.2283
# Batch 6200/40000 (15.5%) - Train Loss: 2.2594, Val Loss: 2.2117
# Batch 6250/40000 (15.6%) - Train Loss: 2.1776, Val Loss: 2.1975
# Batch 6300/40000 (15.8%) - Train Loss: 2.2403, Val Loss: 2.2395
# Batch 6350/40000 (15.9%) - Train Loss: 2.2802, Val Loss: 2.2270
# Batch 6400/40000 (16.0%) - Train Loss: 2.2422, Val Loss: 2.1953
# Batch 6450/40000 (16.1%) - Train Loss: 2.2480, Val Loss: 2.2096
# Batch 6500/40000 (16.2%) - Train Loss: 2.2149, Val Loss: 2.2056
# Batch 6550/40000 (16.4%) - Train Loss: 2.1783, Val Loss: 2.2086
# Batch 6600/40000 (16.5%) - Train Loss: 2.2394, Val Loss: 2.2005
# Batch 6650/40000 (16.6%) - Train Loss: 2.2341, Val Loss: 2.1961
# Batch 6700/40000 (16.8%) - Train Loss: 2.1136, Val Loss: 2.1702
# Batch 6750/40000 (16.9%) - Train Loss: 2.1600, Val Loss: 2.1737
# Batch 6800/40000 (17.0%) - Train Loss: 2.1846, Val Loss: 2.1805
# Batch 6850/40000 (17.1%) - Train Loss: 2.2195, Val Loss: 2.2014
# Batch 6900/40000 (17.2%) - Train Loss: 2.2307, Val Loss: 2.2205
# Batch 6950/40000 (17.4%) - Train Loss: 2.1784, Val Loss: 2.1699
# Batch 7000/40000 (17.5%) - Train Loss: 2.0804, Val Loss: 2.1615
# Batch 7050/40000 (17.6%) - Train Loss: 2.1742, Val Loss: 2.1687
# Batch 7100/40000 (17.8%) - Train Loss: 2.1894, Val Loss: 2.1750
# Batch 7150/40000 (17.9%) - Train Loss: 2.1291, Val Loss: 2.1667
# Batch 7200/40000 (18.0%) - Train Loss: 2.1870, Val Loss: 2.1885
# Batch 7250/40000 (18.1%) - Train Loss: 2.2573, Val Loss: 2.1988
# Batch 7300/40000 (18.2%) - Train Loss: 2.1637, Val Loss: 2.1616
# Batch 7350/40000 (18.4%) - Train Loss: 2.1714, Val Loss: 2.1509
# Batch 7400/40000 (18.5%) - Train Loss: 2.1826, Val Loss: 2.1826
# Batch 7450/40000 (18.6%) - Train Loss: 2.2188, Val Loss: 2.1616
# Batch 7500/40000 (18.8%) - Train Loss: 2.1765, Val Loss: 2.1625
# Batch 7550/40000 (18.9%) - Train Loss: 2.1336, Val Loss: 2.1573
# Batch 7600/40000 (19.0%) - Train Loss: 2.1776, Val Loss: 2.1395
# Batch 7650/40000 (19.1%) - Train Loss: 2.2280, Val Loss: 2.1667
# Batch 7700/40000 (19.2%) - Train Loss: 2.1765, Val Loss: 2.1463
# Batch 7750/40000 (19.4%) - Train Loss: 2.2325, Val Loss: 2.1690
# Batch 7800/40000 (19.5%) - Train Loss: 2.2325, Val Loss: 2.2615
# Batch 7850/40000 (19.6%) - Train Loss: 2.1507, Val Loss: 2.1502
# Batch 7900/40000 (19.8%) - Train Loss: 2.1191, Val Loss: 2.1407
# Batch 7950/40000 (19.9%) - Train Loss: 2.2044, Val Loss: 2.1895
# Batch 8000/40000 (20.0%) - Train Loss: 2.0813, Val Loss: 2.1385
# Batch 8050/40000 (20.1%) - Train Loss: 2.2005, Val Loss: 2.1356
# Batch 8100/40000 (20.2%) - Train Loss: 2.1746, Val Loss: 2.1625
# Batch 8150/40000 (20.4%) - Train Loss: 2.0747, Val Loss: 2.1272
# Batch 8200/40000 (20.5%) - Train Loss: 2.1320, Val Loss: 2.1454
# Batch 8250/40000 (20.6%) - Train Loss: 2.1874, Val Loss: 2.1567
# Batch 8300/40000 (20.8%) - Train Loss: 2.1675, Val Loss: 2.1091
# Batch 8350/40000 (20.9%) - Train Loss: 2.1320, Val Loss: 2.1094
# Batch 8400/40000 (21.0%) - Train Loss: 2.1117, Val Loss: 2.1213
# Batch 8450/40000 (21.1%) - Train Loss: 2.0995, Val Loss: 2.1137
# Batch 8500/40000 (21.2%) - Train Loss: 2.1494, Val Loss: 2.1614
# Batch 8550/40000 (21.4%) - Train Loss: 2.1196, Val Loss: 2.1143
# Batch 8600/40000 (21.5%) - Train Loss: 2.0802, Val Loss: 2.1157
# Batch 8650/40000 (21.6%) - Train Loss: 2.1381, Val Loss: 2.1219
# Batch 8700/40000 (21.8%) - Train Loss: 2.0756, Val Loss: 2.1018
# Batch 8750/40000 (21.9%) - Train Loss: 2.1700, Val Loss: 2.1040
# Batch 8800/40000 (22.0%) - Train Loss: 2.1426, Val Loss: 2.1016
# Batch 8850/40000 (22.1%) - Train Loss: 2.1517, Val Loss: 2.0856
# Batch 8900/40000 (22.2%) - Train Loss: 2.1147, Val Loss: 2.1051
# Batch 8950/40000 (22.4%) - Train Loss: 2.0772, Val Loss: 2.0966
# Batch 9000/40000 (22.5%) - Train Loss: 2.1023, Val Loss: 2.0839
# Batch 9050/40000 (22.6%) - Train Loss: 2.1251, Val Loss: 2.1116
# Batch 9100/40000 (22.8%) - Train Loss: 2.1107, Val Loss: 2.0798
# Batch 9150/40000 (22.9%) - Train Loss: 2.0707, Val Loss: 2.1453
# Batch 9200/40000 (23.0%) - Train Loss: 2.0508, Val Loss: 2.1048
# Batch 9250/40000 (23.1%) - Train Loss: 2.1150, Val Loss: 2.0964
# Batch 9300/40000 (23.2%) - Train Loss: 2.0492, Val Loss: 2.0748
# Batch 9350/40000 (23.4%) - Train Loss: 2.1348, Val Loss: 2.1201
# Batch 9400/40000 (23.5%) - Train Loss: 2.1592, Val Loss: 2.0874
# Batch 9450/40000 (23.6%) - Train Loss: 2.1544, Val Loss: 2.1453
# Batch 9500/40000 (23.8%) - Train Loss: 2.0844, Val Loss: 2.0785
# Batch 9550/40000 (23.9%) - Train Loss: 2.0641, Val Loss: 2.0807
# Batch 9600/40000 (24.0%) - Train Loss: 2.2600, Val Loss: 2.1722
# Batch 9650/40000 (24.1%) - Train Loss: 2.1979, Val Loss: 2.3161
# Batch 9700/40000 (24.2%) - Train Loss: 2.1281, Val Loss: 2.0716
# Batch 9750/40000 (24.4%) - Train Loss: 2.0787, Val Loss: 2.0629
# Batch 9800/40000 (24.5%) - Train Loss: 2.1211, Val Loss: 2.0859
# Batch 9850/40000 (24.6%) - Train Loss: 2.0326, Val Loss: 2.0581
# Batch 9900/40000 (24.8%) - Train Loss: 2.0804, Val Loss: 2.0644
# Batch 9950/40000 (24.9%) - Train Loss: 1.9601, Val Loss: 2.0732
# Batch 10000/40000 (25.0%) - Train Loss: 2.0670, Val Loss: 2.0670
# Batch 10000: Reducing learning rate to 0.007350
# Batch 10050/40000 (25.1%) - Train Loss: 2.0495, Val Loss: 2.0310
# Batch 10100/40000 (25.2%) - Train Loss: 1.9717, Val Loss: 2.0269
# Batch 10150/40000 (25.4%) - Train Loss: 1.9967, Val Loss: 2.0229
# Batch 10200/40000 (25.5%) - Train Loss: 1.9587, Val Loss: 2.0277
# Batch 10250/40000 (25.6%) - Train Loss: 2.0496, Val Loss: 2.0209
# Batch 10300/40000 (25.8%) - Train Loss: 2.0213, Val Loss: 2.0308
# Batch 10350/40000 (25.9%) - Train Loss: 2.0181, Val Loss: 2.0275
# Batch 10400/40000 (26.0%) - Train Loss: 2.0080, Val Loss: 2.0173
# Batch 10450/40000 (26.1%) - Train Loss: 1.9711, Val Loss: 2.0219
# Batch 10500/40000 (26.2%) - Train Loss: 1.9772, Val Loss: 2.0201
# Batch 10550/40000 (26.4%) - Train Loss: 2.0593, Val Loss: 2.0254
# Batch 10600/40000 (26.5%) - Train Loss: 2.0416, Val Loss: 2.0139
# Batch 10650/40000 (26.6%) - Train Loss: 1.9448, Val Loss: 2.0069
# Batch 10700/40000 (26.8%) - Train Loss: 2.0184, Val Loss: 2.0243
# Batch 10750/40000 (26.9%) - Train Loss: 2.0732, Val Loss: 2.0075
# Batch 10800/40000 (27.0%) - Train Loss: 2.0158, Val Loss: 2.0217
# Batch 10850/40000 (27.1%) - Train Loss: 2.1197, Val Loss: 2.0140
# Batch 10900/40000 (27.3%) - Train Loss: 1.9449, Val Loss: 2.0106
# Batch 10950/40000 (27.4%) - Train Loss: 2.0509, Val Loss: 2.0030
# Batch 11000/40000 (27.5%) - Train Loss: 1.9991, Val Loss: 2.0056
# Batch 11050/40000 (27.6%) - Train Loss: 2.0221, Val Loss: 2.0104
# Batch 11100/40000 (27.8%) - Train Loss: 2.0793, Val Loss: 2.0244
# Batch 11150/40000 (27.9%) - Train Loss: 2.0112, Val Loss: 2.0045
# Batch 11200/40000 (28.0%) - Train Loss: 1.9749, Val Loss: 1.9945
# Batch 11250/40000 (28.1%) - Train Loss: 2.0250, Val Loss: 2.0038
# Batch 11300/40000 (28.2%) - Train Loss: 1.9576, Val Loss: 2.0099
# Batch 11350/40000 (28.4%) - Train Loss: 2.1056, Val Loss: 2.0287
# Batch 11400/40000 (28.5%) - Train Loss: 2.0006, Val Loss: 2.0065
# Batch 11450/40000 (28.6%) - Train Loss: 1.9580, Val Loss: 1.9979
# Batch 11500/40000 (28.7%) - Train Loss: 2.0307, Val Loss: 2.0031
# Batch 11550/40000 (28.9%) - Train Loss: 1.9880, Val Loss: 1.9906
# Batch 11600/40000 (29.0%) - Train Loss: 2.0286, Val Loss: 1.9997
# Batch 11650/40000 (29.1%) - Train Loss: 2.0205, Val Loss: 2.0093
# Batch 11700/40000 (29.2%) - Train Loss: 2.0261, Val Loss: 1.9938
# Batch 11750/40000 (29.4%) - Train Loss: 2.0095, Val Loss: 2.0102
# Batch 11800/40000 (29.5%) - Train Loss: 1.9349, Val Loss: 1.9842
# Batch 11850/40000 (29.6%) - Train Loss: 1.9879, Val Loss: 1.9802
# Batch 11900/40000 (29.8%) - Train Loss: 1.9550, Val Loss: 1.9834
# Batch 11950/40000 (29.9%) - Train Loss: 1.9821, Val Loss: 1.9814
# Batch 12000/40000 (30.0%) - Train Loss: 2.0337, Val Loss: 2.0017
# Batch 12050/40000 (30.1%) - Train Loss: 1.9655, Val Loss: 1.9806
# Batch 12100/40000 (30.2%) - Train Loss: 1.9675, Val Loss: 1.9892
# Batch 12150/40000 (30.4%) - Train Loss: 1.9455, Val Loss: 1.9992
# Batch 12200/40000 (30.5%) - Train Loss: 2.0329, Val Loss: 2.0061
# Batch 12250/40000 (30.6%) - Train Loss: 1.9780, Val Loss: 1.9871
# Batch 12300/40000 (30.8%) - Train Loss: 2.0281, Val Loss: 1.9921
# Batch 12350/40000 (30.9%) - Train Loss: 1.9660, Val Loss: 1.9781
# Batch 12400/40000 (31.0%) - Train Loss: 1.9895, Val Loss: 1.9718
# Batch 12450/40000 (31.1%) - Train Loss: 1.9340, Val Loss: 1.9917
# Batch 12500/40000 (31.2%) - Train Loss: 1.9893, Val Loss: 1.9766
# Batch 12550/40000 (31.4%) - Train Loss: 1.9520, Val Loss: 1.9724
# Batch 12600/40000 (31.5%) - Train Loss: 1.9857, Val Loss: 1.9719
# Batch 12650/40000 (31.6%) - Train Loss: 1.9537, Val Loss: 1.9783
# Batch 12700/40000 (31.8%) - Train Loss: 1.9719, Val Loss: 1.9855
# Batch 12750/40000 (31.9%) - Train Loss: 2.0179, Val Loss: 1.9754
# Batch 12800/40000 (32.0%) - Train Loss: 1.9690, Val Loss: 1.9637
# Batch 12850/40000 (32.1%) - Train Loss: 2.0228, Val Loss: 1.9937
# Batch 12900/40000 (32.2%) - Train Loss: 1.9983, Val Loss: 2.0036
# Batch 12950/40000 (32.4%) - Train Loss: 1.9902, Val Loss: 1.9725
# Batch 13000/40000 (32.5%) - Train Loss: 2.0594, Val Loss: 2.0216
# Batch 13050/40000 (32.6%) - Train Loss: 2.0084, Val Loss: 1.9615
# Batch 13100/40000 (32.8%) - Train Loss: 2.0020, Val Loss: 1.9894
# Batch 13150/40000 (32.9%) - Train Loss: 1.9565, Val Loss: 1.9732
# Batch 13200/40000 (33.0%) - Train Loss: 2.0341, Val Loss: 2.0018
# Batch 13250/40000 (33.1%) - Train Loss: 1.9705, Val Loss: 1.9570
# Batch 13300/40000 (33.2%) - Train Loss: 2.0690, Val Loss: 1.9900
# Batch 13350/40000 (33.4%) - Train Loss: 2.0302, Val Loss: 1.9736
# Batch 13400/40000 (33.5%) - Train Loss: 2.0729, Val Loss: 1.9615
# Batch 13450/40000 (33.6%) - Train Loss: 1.9352, Val Loss: 1.9691
# Batch 13500/40000 (33.8%) - Train Loss: 2.0093, Val Loss: 1.9789
# Batch 13550/40000 (33.9%) - Train Loss: 2.0023, Val Loss: 1.9957
# Batch 13600/40000 (34.0%) - Train Loss: 1.9827, Val Loss: 1.9691
# Batch 13650/40000 (34.1%) - Train Loss: 1.9776, Val Loss: 1.9651
# Batch 13700/40000 (34.2%) - Train Loss: 1.9451, Val Loss: 1.9593
# Batch 13750/40000 (34.4%) - Train Loss: 1.9789, Val Loss: 1.9623
# Batch 13800/40000 (34.5%) - Train Loss: 1.9004, Val Loss: 1.9481
# Batch 13850/40000 (34.6%) - Train Loss: 2.0023, Val Loss: 1.9855
# Batch 13900/40000 (34.8%) - Train Loss: 2.0053, Val Loss: 1.9573
# Batch 13950/40000 (34.9%) - Train Loss: 1.9187, Val Loss: 1.9615
# Batch 14000/40000 (35.0%) - Train Loss: 1.9461, Val Loss: 1.9944
# Batch 14050/40000 (35.1%) - Train Loss: 1.9224, Val Loss: 1.9464
# Batch 14100/40000 (35.2%) - Train Loss: 2.0211, Val Loss: 2.0289
# Batch 14150/40000 (35.4%) - Train Loss: 1.9953, Val Loss: 1.9559
# Batch 14200/40000 (35.5%) - Train Loss: 1.9614, Val Loss: 1.9620
# Batch 14250/40000 (35.6%) - Train Loss: 1.9329, Val Loss: 1.9545
# Batch 14300/40000 (35.8%) - Train Loss: 1.9427, Val Loss: 1.9620
# Batch 14350/40000 (35.9%) - Train Loss: 1.9140, Val Loss: 1.9454
# Batch 14400/40000 (36.0%) - Train Loss: 1.9800, Val Loss: 1.9592
# Batch 14450/40000 (36.1%) - Train Loss: 1.9459, Val Loss: 1.9361
# Batch 14500/40000 (36.2%) - Train Loss: 1.9248, Val Loss: 1.9331
# Batch 14550/40000 (36.4%) - Train Loss: 1.9544, Val Loss: 1.9388
# Batch 14600/40000 (36.5%) - Train Loss: 1.9742, Val Loss: 1.9377
# Batch 14650/40000 (36.6%) - Train Loss: 1.9498, Val Loss: 1.9517
# Batch 14700/40000 (36.8%) - Train Loss: 1.9387, Val Loss: 1.9481
# Batch 14750/40000 (36.9%) - Train Loss: 1.9915, Val Loss: 2.0172
# Batch 14800/40000 (37.0%) - Train Loss: 1.9715, Val Loss: 1.9720
# Batch 14850/40000 (37.1%) - Train Loss: 1.9621, Val Loss: 1.9755
# Batch 14900/40000 (37.2%) - Train Loss: 2.0086, Val Loss: 1.9549
# Batch 14950/40000 (37.4%) - Train Loss: 1.8963, Val Loss: 1.9250
# Batch 15000/40000 (37.5%) - Train Loss: 1.9560, Val Loss: 1.9411
# Batch 15000: Reducing learning rate to 0.005145
# Batch 15050/40000 (37.6%) - Train Loss: 1.9018, Val Loss: 1.9046
# Batch 15100/40000 (37.8%) - Train Loss: 1.9191, Val Loss: 1.9054
# Batch 15150/40000 (37.9%) - Train Loss: 1.9366, Val Loss: 1.9068
# Batch 15200/40000 (38.0%) - Train Loss: 1.9225, Val Loss: 1.9107
# Batch 15250/40000 (38.1%) - Train Loss: 1.9259, Val Loss: 1.9025
# Batch 15300/40000 (38.2%) - Train Loss: 1.9083, Val Loss: 1.9066
# Batch 15350/40000 (38.4%) - Train Loss: 1.9695, Val Loss: 1.9035
# Batch 15400/40000 (38.5%) - Train Loss: 1.9184, Val Loss: 1.9078
# Batch 15450/40000 (38.6%) - Train Loss: 1.8971, Val Loss: 1.8938
# Batch 15500/40000 (38.8%) - Train Loss: 1.8826, Val Loss: 1.8974
# Batch 15550/40000 (38.9%) - Train Loss: 1.8928, Val Loss: 1.9042
# Batch 15600/40000 (39.0%) - Train Loss: 1.8653, Val Loss: 1.8958
# Batch 15650/40000 (39.1%) - Train Loss: 1.8609, Val Loss: 1.9003
# Batch 15700/40000 (39.2%) - Train Loss: 1.9686, Val Loss: 1.8958
# Batch 15750/40000 (39.4%) - Train Loss: 1.8567, Val Loss: 1.8974
# Batch 15800/40000 (39.5%) - Train Loss: 1.9561, Val Loss: 1.8929
# Batch 15850/40000 (39.6%) - Train Loss: 1.8644, Val Loss: 1.8998
# Batch 15900/40000 (39.8%) - Train Loss: 1.8835, Val Loss: 1.8926
# Batch 15950/40000 (39.9%) - Train Loss: 1.9511, Val Loss: 1.8981
# Batch 16000/40000 (40.0%) - Train Loss: 1.9178, Val Loss: 1.8905
# Batch 16050/40000 (40.1%) - Train Loss: 1.8625, Val Loss: 1.9000
# Batch 16100/40000 (40.2%) - Train Loss: 1.8717, Val Loss: 1.8921
# Batch 16150/40000 (40.4%) - Train Loss: 1.9388, Val Loss: 1.8977
# Batch 16200/40000 (40.5%) - Train Loss: 1.9149, Val Loss: 1.8966
# Batch 16250/40000 (40.6%) - Train Loss: 1.9159, Val Loss: 1.8919
# Batch 16300/40000 (40.8%) - Train Loss: 1.9232, Val Loss: 1.8979
# Batch 16350/40000 (40.9%) - Train Loss: 1.9139, Val Loss: 1.8903
# Batch 16400/40000 (41.0%) - Train Loss: 1.9176, Val Loss: 1.8905
# Batch 16450/40000 (41.1%) - Train Loss: 1.8913, Val Loss: 1.8880
# Batch 16500/40000 (41.2%) - Train Loss: 1.9580, Val Loss: 1.8927
# Batch 16550/40000 (41.4%) - Train Loss: 1.7962, Val Loss: 1.8953
# Batch 16600/40000 (41.5%) - Train Loss: 1.9133, Val Loss: 1.8911
# Batch 16650/40000 (41.6%) - Train Loss: 1.9545, Val Loss: 1.8830
# Batch 16700/40000 (41.8%) - Train Loss: 1.9024, Val Loss: 1.8877
# Batch 16750/40000 (41.9%) - Train Loss: 1.9051, Val Loss: 1.8913
# Batch 16800/40000 (42.0%) - Train Loss: 1.8829, Val Loss: 1.8854
# Batch 16850/40000 (42.1%) - Train Loss: 1.9379, Val Loss: 1.8795
# Batch 16900/40000 (42.2%) - Train Loss: 1.8606, Val Loss: 1.8822
# Batch 16950/40000 (42.4%) - Train Loss: 1.9188, Val Loss: 1.8753
# Batch 17000/40000 (42.5%) - Train Loss: 1.8391, Val Loss: 1.8842
# Batch 17050/40000 (42.6%) - Train Loss: 1.8831, Val Loss: 1.8825
# Batch 17100/40000 (42.8%) - Train Loss: 1.8962, Val Loss: 1.8870
# Batch 17150/40000 (42.9%) - Train Loss: 1.9340, Val Loss: 1.8748
# Batch 17200/40000 (43.0%) - Train Loss: 1.8582, Val Loss: 1.8828
# Batch 17250/40000 (43.1%) - Train Loss: 1.8399, Val Loss: 1.8868
# Batch 17300/40000 (43.2%) - Train Loss: 1.8933, Val Loss: 1.8797
# Batch 17350/40000 (43.4%) - Train Loss: 1.9205, Val Loss: 1.8860
# Batch 17400/40000 (43.5%) - Train Loss: 1.9196, Val Loss: 1.8764
# Batch 17450/40000 (43.6%) - Train Loss: 1.8934, Val Loss: 1.8734
# Batch 17500/40000 (43.8%) - Train Loss: 1.8429, Val Loss: 1.8824
# Batch 17550/40000 (43.9%) - Train Loss: 1.8179, Val Loss: 1.8822
# Batch 17600/40000 (44.0%) - Train Loss: 1.8656, Val Loss: 1.8718
# Batch 17650/40000 (44.1%) - Train Loss: 1.8703, Val Loss: 1.8776
# Batch 17700/40000 (44.2%) - Train Loss: 1.8765, Val Loss: 1.8846
# Batch 17750/40000 (44.4%) - Train Loss: 1.8524, Val Loss: 1.8874
# Batch 17800/40000 (44.5%) - Train Loss: 1.8479, Val Loss: 1.8913
# Batch 17850/40000 (44.6%) - Train Loss: 1.8256, Val Loss: 1.8696
# Batch 17900/40000 (44.8%) - Train Loss: 1.8588, Val Loss: 1.8729
# Batch 17950/40000 (44.9%) - Train Loss: 1.9068, Val Loss: 1.8716
# Batch 18000/40000 (45.0%) - Train Loss: 1.8501, Val Loss: 1.8739
# Batch 18050/40000 (45.1%) - Train Loss: 1.8950, Val Loss: 1.9192
# Batch 18100/40000 (45.2%) - Train Loss: 1.8675, Val Loss: 1.8753
# Batch 18150/40000 (45.4%) - Train Loss: 1.8940, Val Loss: 1.8682
# Batch 18200/40000 (45.5%) - Train Loss: 1.9255, Val Loss: 1.8993
# Batch 18250/40000 (45.6%) - Train Loss: 1.8387, Val Loss: 1.8804
# Batch 18300/40000 (45.8%) - Train Loss: 1.8620, Val Loss: 1.8729
# Batch 18350/40000 (45.9%) - Train Loss: 1.8439, Val Loss: 1.8608
# Batch 18400/40000 (46.0%) - Train Loss: 1.9063, Val Loss: 1.8710
# Batch 18450/40000 (46.1%) - Train Loss: 1.8993, Val Loss: 1.8766
# Batch 18500/40000 (46.2%) - Train Loss: 1.8818, Val Loss: 1.8711
# Batch 18550/40000 (46.4%) - Train Loss: 1.8708, Val Loss: 1.8699
# Batch 18600/40000 (46.5%) - Train Loss: 1.8890, Val Loss: 1.8768
# Batch 18650/40000 (46.6%) - Train Loss: 1.8291, Val Loss: 1.8666
# Batch 18700/40000 (46.8%) - Train Loss: 1.9510, Val Loss: 1.8828
# Batch 18750/40000 (46.9%) - Train Loss: 1.8677, Val Loss: 1.8629
# Batch 18800/40000 (47.0%) - Train Loss: 1.8614, Val Loss: 1.8595
# Batch 18850/40000 (47.1%) - Train Loss: 1.8156, Val Loss: 1.8590
# Batch 18900/40000 (47.2%) - Train Loss: 1.8929, Val Loss: 1.8642
# Batch 18950/40000 (47.4%) - Train Loss: 1.9438, Val Loss: 1.8833
# Batch 19000/40000 (47.5%) - Train Loss: 1.8262, Val Loss: 1.8633
# Batch 19050/40000 (47.6%) - Train Loss: 1.8234, Val Loss: 1.8564
# Batch 19100/40000 (47.8%) - Train Loss: 1.9314, Val Loss: 1.8795
# Batch 19150/40000 (47.9%) - Train Loss: 1.8553, Val Loss: 1.8831
# Batch 19200/40000 (48.0%) - Train Loss: 1.9519, Val Loss: 1.8580
# Batch 19250/40000 (48.1%) - Train Loss: 1.8942, Val Loss: 1.8557
# Batch 19300/40000 (48.2%) - Train Loss: 1.8623, Val Loss: 1.8711
# Batch 19350/40000 (48.4%) - Train Loss: 1.8724, Val Loss: 1.8769
# Batch 19400/40000 (48.5%) - Train Loss: 1.7806, Val Loss: 1.8602
# Batch 19450/40000 (48.6%) - Train Loss: 1.9034, Val Loss: 1.8548
# Batch 19500/40000 (48.8%) - Train Loss: 1.8578, Val Loss: 1.8656
# Batch 19550/40000 (48.9%) - Train Loss: 1.8974, Val Loss: 1.8658
# Batch 19600/40000 (49.0%) - Train Loss: 1.9261, Val Loss: 1.8715
# Batch 19650/40000 (49.1%) - Train Loss: 1.8517, Val Loss: 1.8804
# Batch 19700/40000 (49.2%) - Train Loss: 1.8773, Val Loss: 1.8559
# Batch 19750/40000 (49.4%) - Train Loss: 1.8376, Val Loss: 1.8600
# Batch 19800/40000 (49.5%) - Train Loss: 1.8531, Val Loss: 1.8626
# Batch 19850/40000 (49.6%) - Train Loss: 1.8766, Val Loss: 1.8572
# Batch 19900/40000 (49.8%) - Train Loss: 1.9020, Val Loss: 1.8472
# Batch 19950/40000 (49.9%) - Train Loss: 1.9522, Val Loss: 1.8853
# Batch 20000/40000 (50.0%) - Train Loss: 1.7917, Val Loss: 1.8612
# Batch 20000: Reducing learning rate to 0.003601
# Batch 20050/40000 (50.1%) - Train Loss: 1.8515, Val Loss: 1.8349
# Batch 20100/40000 (50.2%) - Train Loss: 1.7981, Val Loss: 1.8327
# Batch 20150/40000 (50.4%) - Train Loss: 1.8480, Val Loss: 1.8268
# Batch 20200/40000 (50.5%) - Train Loss: 1.8360, Val Loss: 1.8321
# Batch 20250/40000 (50.6%) - Train Loss: 1.8618, Val Loss: 1.8289
# Batch 20300/40000 (50.7%) - Train Loss: 1.8223, Val Loss: 1.8338
# Batch 20350/40000 (50.9%) - Train Loss: 1.7977, Val Loss: 1.8246
# Batch 20400/40000 (51.0%) - Train Loss: 1.8671, Val Loss: 1.8277
# Batch 20450/40000 (51.1%) - Train Loss: 1.8040, Val Loss: 1.8300
# Batch 20500/40000 (51.2%) - Train Loss: 1.8901, Val Loss: 1.8241
# Batch 20550/40000 (51.4%) - Train Loss: 1.8178, Val Loss: 1.8287
# Batch 20600/40000 (51.5%) - Train Loss: 1.8522, Val Loss: 1.8296
# Batch 20650/40000 (51.6%) - Train Loss: 1.8000, Val Loss: 1.8325
# Batch 20700/40000 (51.7%) - Train Loss: 1.8518, Val Loss: 1.8267
# Batch 20750/40000 (51.9%) - Train Loss: 1.8878, Val Loss: 1.8305
# Batch 20800/40000 (52.0%) - Train Loss: 1.8675, Val Loss: 1.8271
# Batch 20850/40000 (52.1%) - Train Loss: 1.8683, Val Loss: 1.8233
# Batch 20900/40000 (52.2%) - Train Loss: 1.8069, Val Loss: 1.8244
# Batch 20950/40000 (52.4%) - Train Loss: 1.8221, Val Loss: 1.8263
# Batch 21000/40000 (52.5%) - Train Loss: 1.8497, Val Loss: 1.8306
# Batch 21050/40000 (52.6%) - Train Loss: 1.8301, Val Loss: 1.8237
# Batch 21100/40000 (52.8%) - Train Loss: 1.8417, Val Loss: 1.8355
# Batch 21150/40000 (52.9%) - Train Loss: 1.8817, Val Loss: 1.8290
# Batch 21200/40000 (53.0%) - Train Loss: 1.8588, Val Loss: 1.8218
# Batch 21250/40000 (53.1%) - Train Loss: 1.8557, Val Loss: 1.8255
# Batch 21300/40000 (53.2%) - Train Loss: 1.7683, Val Loss: 1.8193
# Batch 21350/40000 (53.4%) - Train Loss: 1.9223, Val Loss: 1.8225
# Batch 21400/40000 (53.5%) - Train Loss: 1.8043, Val Loss: 1.8195
# Batch 21450/40000 (53.6%) - Train Loss: 1.7844, Val Loss: 1.8166
# Batch 21500/40000 (53.8%) - Train Loss: 1.8069, Val Loss: 1.8221
# Batch 21550/40000 (53.9%) - Train Loss: 1.7735, Val Loss: 1.8180
# Batch 21600/40000 (54.0%) - Train Loss: 1.8300, Val Loss: 1.8191
# Batch 21650/40000 (54.1%) - Train Loss: 1.8934, Val Loss: 1.8206
# Batch 21700/40000 (54.2%) - Train Loss: 1.9061, Val Loss: 1.8331
# Batch 21750/40000 (54.4%) - Train Loss: 1.8517, Val Loss: 1.8160
# Batch 21800/40000 (54.5%) - Train Loss: 1.8559, Val Loss: 1.8195
# Batch 21850/40000 (54.6%) - Train Loss: 1.7373, Val Loss: 1.8158
# Batch 21900/40000 (54.8%) - Train Loss: 1.7839, Val Loss: 1.8182
# Batch 21950/40000 (54.9%) - Train Loss: 1.8190, Val Loss: 1.8233
# Batch 22000/40000 (55.0%) - Train Loss: 1.8356, Val Loss: 1.8171
# Batch 22050/40000 (55.1%) - Train Loss: 1.8358, Val Loss: 1.8127
# Batch 22100/40000 (55.2%) - Train Loss: 1.7687, Val Loss: 1.8149
# Batch 22150/40000 (55.4%) - Train Loss: 1.8490, Val Loss: 1.8251
# Batch 22200/40000 (55.5%) - Train Loss: 1.8796, Val Loss: 1.8196
# Batch 22250/40000 (55.6%) - Train Loss: 1.8364, Val Loss: 1.8126
# Batch 22300/40000 (55.8%) - Train Loss: 1.7886, Val Loss: 1.8180
# Batch 22350/40000 (55.9%) - Train Loss: 1.8336, Val Loss: 1.8106
# Batch 22400/40000 (56.0%) - Train Loss: 1.8221, Val Loss: 1.8104
# Batch 22450/40000 (56.1%) - Train Loss: 1.7753, Val Loss: 1.8148
# Batch 22500/40000 (56.2%) - Train Loss: 1.8044, Val Loss: 1.8112
# Batch 22550/40000 (56.4%) - Train Loss: 1.8238, Val Loss: 1.8192
# Batch 22600/40000 (56.5%) - Train Loss: 1.8351, Val Loss: 1.8100
# Batch 22650/40000 (56.6%) - Train Loss: 1.7755, Val Loss: 1.8117
# Batch 22700/40000 (56.8%) - Train Loss: 1.8277, Val Loss: 1.8095
# Batch 22750/40000 (56.9%) - Train Loss: 1.7777, Val Loss: 1.8034
# Batch 22800/40000 (57.0%) - Train Loss: 1.7976, Val Loss: 1.8104
# Batch 22850/40000 (57.1%) - Train Loss: 1.8113, Val Loss: 1.8112
# Batch 22900/40000 (57.2%) - Train Loss: 1.8118, Val Loss: 1.8127
# Batch 22950/40000 (57.4%) - Train Loss: 1.8340, Val Loss: 1.8128
# Batch 23000/40000 (57.5%) - Train Loss: 1.8358, Val Loss: 1.8065
# Batch 23050/40000 (57.6%) - Train Loss: 1.8223, Val Loss: 1.8067
# Batch 23100/40000 (57.8%) - Train Loss: 1.8589, Val Loss: 1.8109
# Batch 23150/40000 (57.9%) - Train Loss: 1.8113, Val Loss: 1.8095
# Batch 23200/40000 (58.0%) - Train Loss: 1.8303, Val Loss: 1.8088
# Batch 23250/40000 (58.1%) - Train Loss: 1.8486, Val Loss: 1.8060
# Batch 23300/40000 (58.2%) - Train Loss: 1.7219, Val Loss: 1.8101
# Batch 23350/40000 (58.4%) - Train Loss: 1.8395, Val Loss: 1.8094
# Batch 23400/40000 (58.5%) - Train Loss: 1.7975, Val Loss: 1.8018
# Batch 23450/40000 (58.6%) - Train Loss: 1.8388, Val Loss: 1.7994
# Batch 23500/40000 (58.8%) - Train Loss: 1.8696, Val Loss: 1.8092
# Batch 23550/40000 (58.9%) - Train Loss: 1.7988, Val Loss: 1.8091
# Batch 23600/40000 (59.0%) - Train Loss: 1.7400, Val Loss: 1.8042
# Batch 23650/40000 (59.1%) - Train Loss: 1.7989, Val Loss: 1.8104
# Batch 23700/40000 (59.2%) - Train Loss: 1.8204, Val Loss: 1.8047
# Batch 23750/40000 (59.4%) - Train Loss: 1.7670, Val Loss: 1.7985
# Batch 23800/40000 (59.5%) - Train Loss: 1.8367, Val Loss: 1.8137
# Batch 23850/40000 (59.6%) - Train Loss: 1.8425, Val Loss: 1.8062
# Batch 23900/40000 (59.8%) - Train Loss: 1.8011, Val Loss: 1.8153
# Batch 23950/40000 (59.9%) - Train Loss: 1.8189, Val Loss: 1.8012
# Batch 24000/40000 (60.0%) - Train Loss: 1.8204, Val Loss: 1.8060
# Batch 24050/40000 (60.1%) - Train Loss: 1.8633, Val Loss: 1.8086
# Batch 24100/40000 (60.2%) - Train Loss: 1.8466, Val Loss: 1.7977
# Batch 24150/40000 (60.4%) - Train Loss: 1.7774, Val Loss: 1.7996
# Batch 24200/40000 (60.5%) - Train Loss: 1.7331, Val Loss: 1.7999
# Batch 24250/40000 (60.6%) - Train Loss: 1.7902, Val Loss: 1.8010
# Batch 24300/40000 (60.8%) - Train Loss: 1.8099, Val Loss: 1.8021
# Batch 24350/40000 (60.9%) - Train Loss: 1.7492, Val Loss: 1.7981
# Batch 24400/40000 (61.0%) - Train Loss: 1.8488, Val Loss: 1.7964
# Batch 24450/40000 (61.1%) - Train Loss: 1.8065, Val Loss: 1.7933
# Batch 24500/40000 (61.3%) - Train Loss: 1.8153, Val Loss: 1.8052
# Batch 24550/40000 (61.4%) - Train Loss: 1.8598, Val Loss: 1.8004
# Batch 24600/40000 (61.5%) - Train Loss: 1.8418, Val Loss: 1.8044
# Batch 24650/40000 (61.6%) - Train Loss: 1.8582, Val Loss: 1.7937
# Batch 24700/40000 (61.8%) - Train Loss: 1.7552, Val Loss: 1.7983
# Batch 24750/40000 (61.9%) - Train Loss: 1.8106, Val Loss: 1.7895
# Batch 24800/40000 (62.0%) - Train Loss: 1.8174, Val Loss: 1.7998
# Batch 24850/40000 (62.1%) - Train Loss: 1.8328, Val Loss: 1.7981
# Batch 24900/40000 (62.3%) - Train Loss: 1.8330, Val Loss: 1.8105
# Batch 24950/40000 (62.4%) - Train Loss: 1.7725, Val Loss: 1.8083
# Batch 25000/40000 (62.5%) - Train Loss: 1.8044, Val Loss: 1.7928
# Batch 25000: Reducing learning rate to 0.002521
# Batch 25050/40000 (62.6%) - Train Loss: 1.7859, Val Loss: 1.7838
# Batch 25100/40000 (62.7%) - Train Loss: 1.7563, Val Loss: 1.7817
# Batch 25150/40000 (62.9%) - Train Loss: 1.8200, Val Loss: 1.7808
# Batch 25200/40000 (63.0%) - Train Loss: 1.7145, Val Loss: 1.7856
# Batch 25250/40000 (63.1%) - Train Loss: 1.7973, Val Loss: 1.7823
# Batch 25300/40000 (63.2%) - Train Loss: 1.8022, Val Loss: 1.7804
# Batch 25350/40000 (63.4%) - Train Loss: 1.8102, Val Loss: 1.7792
# Batch 25400/40000 (63.5%) - Train Loss: 1.8384, Val Loss: 1.7798
# Batch 25450/40000 (63.6%) - Train Loss: 1.8028, Val Loss: 1.7828
# Batch 25500/40000 (63.7%) - Train Loss: 1.8023, Val Loss: 1.7794
# Batch 25550/40000 (63.9%) - Train Loss: 1.7894, Val Loss: 1.7776
# Batch 25600/40000 (64.0%) - Train Loss: 1.7531, Val Loss: 1.7786
# Batch 25650/40000 (64.1%) - Train Loss: 1.8316, Val Loss: 1.7783
# Batch 25700/40000 (64.2%) - Train Loss: 1.7958, Val Loss: 1.7776
# Batch 25750/40000 (64.4%) - Train Loss: 1.7884, Val Loss: 1.7749
# Batch 25800/40000 (64.5%) - Train Loss: 1.7751, Val Loss: 1.7745
# Batch 25850/40000 (64.6%) - Train Loss: 1.7827, Val Loss: 1.7773
# Batch 25900/40000 (64.8%) - Train Loss: 1.8110, Val Loss: 1.7824
# Batch 25950/40000 (64.9%) - Train Loss: 1.7840, Val Loss: 1.7757
# Batch 26000/40000 (65.0%) - Train Loss: 1.8126, Val Loss: 1.7741
# Batch 26050/40000 (65.1%) - Train Loss: 1.7428, Val Loss: 1.7780
# Batch 26100/40000 (65.2%) - Train Loss: 1.7926, Val Loss: 1.7801
# Batch 26150/40000 (65.4%) - Train Loss: 1.7143, Val Loss: 1.7763
# Batch 26200/40000 (65.5%) - Train Loss: 1.7984, Val Loss: 1.7790
# Batch 26250/40000 (65.6%) - Train Loss: 1.7630, Val Loss: 1.7788
# Batch 26300/40000 (65.8%) - Train Loss: 1.7727, Val Loss: 1.7761
# Batch 26350/40000 (65.9%) - Train Loss: 1.7661, Val Loss: 1.7802
# Batch 26400/40000 (66.0%) - Train Loss: 1.7212, Val Loss: 1.7792
# Batch 26450/40000 (66.1%) - Train Loss: 1.7864, Val Loss: 1.7719
# Batch 26500/40000 (66.2%) - Train Loss: 1.7638, Val Loss: 1.7726
# Batch 26550/40000 (66.4%) - Train Loss: 1.6806, Val Loss: 1.7765
# Batch 26600/40000 (66.5%) - Train Loss: 1.8012, Val Loss: 1.7732
# Batch 26650/40000 (66.6%) - Train Loss: 1.7920, Val Loss: 1.7704
# Batch 26700/40000 (66.8%) - Train Loss: 1.7420, Val Loss: 1.7775
# Batch 26750/40000 (66.9%) - Train Loss: 1.7909, Val Loss: 1.7759
# Batch 26800/40000 (67.0%) - Train Loss: 1.7661, Val Loss: 1.7733
# Batch 26850/40000 (67.1%) - Train Loss: 1.7173, Val Loss: 1.7697
# Batch 26900/40000 (67.2%) - Train Loss: 1.7780, Val Loss: 1.7714
# Batch 26950/40000 (67.4%) - Train Loss: 1.8515, Val Loss: 1.7730
# Batch 27000/40000 (67.5%) - Train Loss: 1.8277, Val Loss: 1.7845
# Batch 27050/40000 (67.6%) - Train Loss: 1.7289, Val Loss: 1.7698
# Batch 27100/40000 (67.8%) - Train Loss: 1.7946, Val Loss: 1.7730
# Batch 27150/40000 (67.9%) - Train Loss: 1.7262, Val Loss: 1.7750
# Batch 27200/40000 (68.0%) - Train Loss: 1.8035, Val Loss: 1.7753
# Batch 27250/40000 (68.1%) - Train Loss: 1.7352, Val Loss: 1.7680
# Batch 27300/40000 (68.2%) - Train Loss: 1.8602, Val Loss: 1.7719
# Batch 27350/40000 (68.4%) - Train Loss: 1.7928, Val Loss: 1.7751
# Batch 27400/40000 (68.5%) - Train Loss: 1.7581, Val Loss: 1.7710
# Batch 27450/40000 (68.6%) - Train Loss: 1.7708, Val Loss: 1.7700
# Batch 27500/40000 (68.8%) - Train Loss: 1.7732, Val Loss: 1.7660
# Batch 27550/40000 (68.9%) - Train Loss: 1.7412, Val Loss: 1.7685
# Batch 27600/40000 (69.0%) - Train Loss: 1.7318, Val Loss: 1.7687
# Batch 27650/40000 (69.1%) - Train Loss: 1.8073, Val Loss: 1.7769
# Batch 27700/40000 (69.2%) - Train Loss: 1.8025, Val Loss: 1.7708
# Batch 27750/40000 (69.4%) - Train Loss: 1.7957, Val Loss: 1.7716
# Batch 27800/40000 (69.5%) - Train Loss: 1.8091, Val Loss: 1.7672
# Batch 27850/40000 (69.6%) - Train Loss: 1.7714, Val Loss: 1.7684
# Batch 27900/40000 (69.8%) - Train Loss: 1.7897, Val Loss: 1.7659
# Batch 27950/40000 (69.9%) - Train Loss: 1.7788, Val Loss: 1.7678
# Batch 28000/40000 (70.0%) - Train Loss: 1.8106, Val Loss: 1.7699
# Batch 28050/40000 (70.1%) - Train Loss: 1.7527, Val Loss: 1.7671
# Batch 28100/40000 (70.2%) - Train Loss: 1.7267, Val Loss: 1.7701
# Batch 28150/40000 (70.4%) - Train Loss: 1.7524, Val Loss: 1.7609
# Batch 28200/40000 (70.5%) - Train Loss: 1.7980, Val Loss: 1.7627
# Batch 28250/40000 (70.6%) - Train Loss: 1.7514, Val Loss: 1.7701
# Batch 28300/40000 (70.8%) - Train Loss: 1.7102, Val Loss: 1.7691
# Batch 28350/40000 (70.9%) - Train Loss: 1.7763, Val Loss: 1.7628
# Batch 28400/40000 (71.0%) - Train Loss: 1.8042, Val Loss: 1.7680
# Batch 28450/40000 (71.1%) - Train Loss: 1.7212, Val Loss: 1.7656
# Batch 28500/40000 (71.2%) - Train Loss: 1.7372, Val Loss: 1.7644
# Batch 28550/40000 (71.4%) - Train Loss: 1.7404, Val Loss: 1.7625
# Batch 28600/40000 (71.5%) - Train Loss: 1.7557, Val Loss: 1.7653
# Batch 28650/40000 (71.6%) - Train Loss: 1.7608, Val Loss: 1.7646
# Batch 28700/40000 (71.8%) - Train Loss: 1.7631, Val Loss: 1.7658
# Batch 28750/40000 (71.9%) - Train Loss: 1.7754, Val Loss: 1.7611
# Batch 28800/40000 (72.0%) - Train Loss: 1.8328, Val Loss: 1.7609
# Batch 28850/40000 (72.1%) - Train Loss: 1.7477, Val Loss: 1.7616
# Batch 28900/40000 (72.2%) - Train Loss: 1.7737, Val Loss: 1.7653
# Batch 28950/40000 (72.4%) - Train Loss: 1.7961, Val Loss: 1.7661
# Batch 29000/40000 (72.5%) - Train Loss: 1.7431, Val Loss: 1.7583
# Batch 29050/40000 (72.6%) - Train Loss: 1.7682, Val Loss: 1.7709
# Batch 29100/40000 (72.8%) - Train Loss: 1.7552, Val Loss: 1.7597
# Batch 29150/40000 (72.9%) - Train Loss: 1.7883, Val Loss: 1.7595
# Batch 29200/40000 (73.0%) - Train Loss: 1.7340, Val Loss: 1.7631
# Batch 29250/40000 (73.1%) - Train Loss: 1.7639, Val Loss: 1.7583
# Batch 29300/40000 (73.2%) - Train Loss: 1.7440, Val Loss: 1.7599
# Batch 29350/40000 (73.4%) - Train Loss: 1.8546, Val Loss: 1.7585
# Batch 29400/40000 (73.5%) - Train Loss: 1.7414, Val Loss: 1.7648
# Batch 29450/40000 (73.6%) - Train Loss: 1.7599, Val Loss: 1.7600
# Batch 29500/40000 (73.8%) - Train Loss: 1.8144, Val Loss: 1.7626
# Batch 29550/40000 (73.9%) - Train Loss: 1.7887, Val Loss: 1.7616
# Batch 29600/40000 (74.0%) - Train Loss: 1.7187, Val Loss: 1.7650
# Batch 29650/40000 (74.1%) - Train Loss: 1.7443, Val Loss: 1.7656
# Batch 29700/40000 (74.2%) - Train Loss: 1.7902, Val Loss: 1.7615
# Batch 29750/40000 (74.4%) - Train Loss: 1.7497, Val Loss: 1.7557
# Batch 29800/40000 (74.5%) - Train Loss: 1.7654, Val Loss: 1.7577
# Batch 29850/40000 (74.6%) - Train Loss: 1.7066, Val Loss: 1.7559
# Batch 29900/40000 (74.8%) - Train Loss: 1.7434, Val Loss: 1.7567
# Batch 29950/40000 (74.9%) - Train Loss: 1.7014, Val Loss: 1.7597
# Batch 30000/40000 (75.0%) - Train Loss: 1.7092, Val Loss: 1.7604
# Batch 30000: Reducing learning rate to 0.001765
# Batch 30050/40000 (75.1%) - Train Loss: 1.7276, Val Loss: 1.7466
# Batch 30100/40000 (75.2%) - Train Loss: 1.7188, Val Loss: 1.7464
# Batch 30150/40000 (75.4%) - Train Loss: 1.7261, Val Loss: 1.7481
# Batch 30200/40000 (75.5%) - Train Loss: 1.7387, Val Loss: 1.7494
# Batch 30250/40000 (75.6%) - Train Loss: 1.8140, Val Loss: 1.7501
# Batch 30300/40000 (75.8%) - Train Loss: 1.7552, Val Loss: 1.7448
# Batch 30350/40000 (75.9%) - Train Loss: 1.7559, Val Loss: 1.7490
# Batch 30400/40000 (76.0%) - Train Loss: 1.7696, Val Loss: 1.7455
# Batch 30450/40000 (76.1%) - Train Loss: 1.7663, Val Loss: 1.7447
# Batch 30500/40000 (76.2%) - Train Loss: 1.7717, Val Loss: 1.7476
# Batch 30550/40000 (76.4%) - Train Loss: 1.7293, Val Loss: 1.7482
# Batch 30600/40000 (76.5%) - Train Loss: 1.7410, Val Loss: 1.7472
# Batch 30650/40000 (76.6%) - Train Loss: 1.7473, Val Loss: 1.7443
# Batch 30700/40000 (76.8%) - Train Loss: 1.7357, Val Loss: 1.7467
# Batch 30750/40000 (76.9%) - Train Loss: 1.7644, Val Loss: 1.7452
# Batch 30800/40000 (77.0%) - Train Loss: 1.7519, Val Loss: 1.7495
# Batch 30850/40000 (77.1%) - Train Loss: 1.7615, Val Loss: 1.7473
# Batch 30900/40000 (77.2%) - Train Loss: 1.7650, Val Loss: 1.7439
# Batch 30950/40000 (77.4%) - Train Loss: 1.7146, Val Loss: 1.7457
# Batch 31000/40000 (77.5%) - Train Loss: 1.7583, Val Loss: 1.7462
# Batch 31050/40000 (77.6%) - Train Loss: 1.7507, Val Loss: 1.7443
# Batch 31100/40000 (77.8%) - Train Loss: 1.7668, Val Loss: 1.7458
# Batch 31150/40000 (77.9%) - Train Loss: 1.7164, Val Loss: 1.7450
# Batch 31200/40000 (78.0%) - Train Loss: 1.7047, Val Loss: 1.7436
# Batch 31250/40000 (78.1%) - Train Loss: 1.7931, Val Loss: 1.7481
# Batch 31300/40000 (78.2%) - Train Loss: 1.6730, Val Loss: 1.7437
# Batch 31350/40000 (78.4%) - Train Loss: 1.7053, Val Loss: 1.7444
# Batch 31400/40000 (78.5%) - Train Loss: 1.7663, Val Loss: 1.7433
# Batch 31450/40000 (78.6%) - Train Loss: 1.7453, Val Loss: 1.7429
# Batch 31500/40000 (78.8%) - Train Loss: 1.7666, Val Loss: 1.7428
# Batch 31550/40000 (78.9%) - Train Loss: 1.7603, Val Loss: 1.7438
# Batch 31600/40000 (79.0%) - Train Loss: 1.8062, Val Loss: 1.7433
# Batch 31650/40000 (79.1%) - Train Loss: 1.7511, Val Loss: 1.7458
# Batch 31700/40000 (79.2%) - Train Loss: 1.7654, Val Loss: 1.7414
# Batch 31750/40000 (79.4%) - Train Loss: 1.7507, Val Loss: 1.7418
# Batch 31800/40000 (79.5%) - Train Loss: 1.7466, Val Loss: 1.7426
# Batch 31850/40000 (79.6%) - Train Loss: 1.6493, Val Loss: 1.7441
# Batch 31900/40000 (79.8%) - Train Loss: 1.7460, Val Loss: 1.7408
# Batch 31950/40000 (79.9%) - Train Loss: 1.7449, Val Loss: 1.7409
# Batch 32000/40000 (80.0%) - Train Loss: 1.7594, Val Loss: 1.7409
# Batch 32050/40000 (80.1%) - Train Loss: 1.7773, Val Loss: 1.7390
# Batch 32100/40000 (80.2%) - Train Loss: 1.7483, Val Loss: 1.7416
# Batch 32150/40000 (80.4%) - Train Loss: 1.7696, Val Loss: 1.7390
# Batch 32200/40000 (80.5%) - Train Loss: 1.7496, Val Loss: 1.7385
# Batch 32250/40000 (80.6%) - Train Loss: 1.7589, Val Loss: 1.7424
# Batch 32300/40000 (80.8%) - Train Loss: 1.6592, Val Loss: 1.7424
# Batch 32350/40000 (80.9%) - Train Loss: 1.7131, Val Loss: 1.7395
# Batch 32400/40000 (81.0%) - Train Loss: 1.7583, Val Loss: 1.7390
# Batch 32450/40000 (81.1%) - Train Loss: 1.7023, Val Loss: 1.7383
# Batch 32500/40000 (81.2%) - Train Loss: 1.7257, Val Loss: 1.7405
# Batch 32550/40000 (81.4%) - Train Loss: 1.7253, Val Loss: 1.7399
# Batch 32600/40000 (81.5%) - Train Loss: 1.7666, Val Loss: 1.7402
# Batch 32650/40000 (81.6%) - Train Loss: 1.7342, Val Loss: 1.7408
# Batch 32700/40000 (81.8%) - Train Loss: 1.7535, Val Loss: 1.7372
# Batch 32750/40000 (81.9%) - Train Loss: 1.7320, Val Loss: 1.7393
# Batch 32800/40000 (82.0%) - Train Loss: 1.7419, Val Loss: 1.7372
# Batch 32850/40000 (82.1%) - Train Loss: 1.7155, Val Loss: 1.7400
# Batch 32900/40000 (82.2%) - Train Loss: 1.7716, Val Loss: 1.7398
# Batch 32950/40000 (82.4%) - Train Loss: 1.7131, Val Loss: 1.7362
# Batch 33000/40000 (82.5%) - Train Loss: 1.7744, Val Loss: 1.7381
# Batch 33050/40000 (82.6%) - Train Loss: 1.7566, Val Loss: 1.7376
# Batch 33100/40000 (82.8%) - Train Loss: 1.7123, Val Loss: 1.7387
# Batch 33150/40000 (82.9%) - Train Loss: 1.7689, Val Loss: 1.7363
# Batch 33200/40000 (83.0%) - Train Loss: 1.8071, Val Loss: 1.7390
# Batch 33250/40000 (83.1%) - Train Loss: 1.7217, Val Loss: 1.7341
# Batch 33300/40000 (83.2%) - Train Loss: 1.7422, Val Loss: 1.7353
# Batch 33350/40000 (83.4%) - Train Loss: 1.6685, Val Loss: 1.7370
# Batch 33400/40000 (83.5%) - Train Loss: 1.7142, Val Loss: 1.7356
# Batch 33450/40000 (83.6%) - Train Loss: 1.7052, Val Loss: 1.7368
# Batch 33500/40000 (83.8%) - Train Loss: 1.7055, Val Loss: 1.7348
# Batch 33550/40000 (83.9%) - Train Loss: 1.7410, Val Loss: 1.7342
# Batch 33600/40000 (84.0%) - Train Loss: 1.7207, Val Loss: 1.7365
# Batch 33650/40000 (84.1%) - Train Loss: 1.7420, Val Loss: 1.7367
# Batch 33700/40000 (84.2%) - Train Loss: 1.7643, Val Loss: 1.7347
# Batch 33750/40000 (84.4%) - Train Loss: 1.7261, Val Loss: 1.7351
# Batch 33800/40000 (84.5%) - Train Loss: 1.6736, Val Loss: 1.7360
# Batch 33850/40000 (84.6%) - Train Loss: 1.7121, Val Loss: 1.7325
# Batch 33900/40000 (84.8%) - Train Loss: 1.7890, Val Loss: 1.7343
# Batch 33950/40000 (84.9%) - Train Loss: 1.7885, Val Loss: 1.7338
# Batch 34000/40000 (85.0%) - Train Loss: 1.7396, Val Loss: 1.7337
# Batch 34050/40000 (85.1%) - Train Loss: 1.8073, Val Loss: 1.7357
# Batch 34100/40000 (85.2%) - Train Loss: 1.7632, Val Loss: 1.7310
# Batch 34150/40000 (85.4%) - Train Loss: 1.7422, Val Loss: 1.7353
# Batch 34200/40000 (85.5%) - Train Loss: 1.7835, Val Loss: 1.7321
# Batch 34250/40000 (85.6%) - Train Loss: 1.7125, Val Loss: 1.7346
# Batch 34300/40000 (85.8%) - Train Loss: 1.6513, Val Loss: 1.7353
# Batch 34350/40000 (85.9%) - Train Loss: 1.7606, Val Loss: 1.7321
# Batch 34400/40000 (86.0%) - Train Loss: 1.7016, Val Loss: 1.7348
# Batch 34450/40000 (86.1%) - Train Loss: 1.7442, Val Loss: 1.7344
# Batch 34500/40000 (86.2%) - Train Loss: 1.7369, Val Loss: 1.7331
# Batch 34550/40000 (86.4%) - Train Loss: 1.6926, Val Loss: 1.7317
# Batch 34600/40000 (86.5%) - Train Loss: 1.7374, Val Loss: 1.7351
# Batch 34650/40000 (86.6%) - Train Loss: 1.7395, Val Loss: 1.7323
# Batch 34700/40000 (86.8%) - Train Loss: 1.7208, Val Loss: 1.7290
# Batch 34750/40000 (86.9%) - Train Loss: 1.7241, Val Loss: 1.7290
# Batch 34800/40000 (87.0%) - Train Loss: 1.7283, Val Loss: 1.7281
# Batch 34850/40000 (87.1%) - Train Loss: 1.7529, Val Loss: 1.7359
# Batch 34900/40000 (87.2%) - Train Loss: 1.7297, Val Loss: 1.7338
# Batch 34950/40000 (87.4%) - Train Loss: 1.7356, Val Loss: 1.7276
# Batch 35000/40000 (87.5%) - Train Loss: 1.6894, Val Loss: 1.7333
# Batch 35000: Reducing learning rate to 0.001235
# Batch 35050/40000 (87.6%) - Train Loss: 1.7003, Val Loss: 1.7260
# Batch 35100/40000 (87.8%) - Train Loss: 1.6938, Val Loss: 1.7266
# Batch 35150/40000 (87.9%) - Train Loss: 1.7123, Val Loss: 1.7262
# Batch 35200/40000 (88.0%) - Train Loss: 1.7219, Val Loss: 1.7254
# Batch 35250/40000 (88.1%) - Train Loss: 1.7252, Val Loss: 1.7268
# Batch 35300/40000 (88.2%) - Train Loss: 1.7239, Val Loss: 1.7266
# Batch 35350/40000 (88.4%) - Train Loss: 1.7742, Val Loss: 1.7248
# Batch 35400/40000 (88.5%) - Train Loss: 1.6885, Val Loss: 1.7229
# Batch 35450/40000 (88.6%) - Train Loss: 1.6837, Val Loss: 1.7237
# Batch 35500/40000 (88.8%) - Train Loss: 1.7229, Val Loss: 1.7253
# Batch 35550/40000 (88.9%) - Train Loss: 1.6904, Val Loss: 1.7242
# Batch 35600/40000 (89.0%) - Train Loss: 1.7329, Val Loss: 1.7241
# Batch 35650/40000 (89.1%) - Train Loss: 1.6979, Val Loss: 1.7230
# Batch 35700/40000 (89.2%) - Train Loss: 1.7484, Val Loss: 1.7231
# Batch 35750/40000 (89.4%) - Train Loss: 1.7635, Val Loss: 1.7234
# Batch 35800/40000 (89.5%) - Train Loss: 1.7507, Val Loss: 1.7240
# Batch 35850/40000 (89.6%) - Train Loss: 1.7906, Val Loss: 1.7227
# Batch 35900/40000 (89.8%) - Train Loss: 1.7475, Val Loss: 1.7238
# Batch 35950/40000 (89.9%) - Train Loss: 1.7663, Val Loss: 1.7217
# Batch 36000/40000 (90.0%) - Train Loss: 1.7114, Val Loss: 1.7229
# Batch 36050/40000 (90.1%) - Train Loss: 1.7845, Val Loss: 1.7230
# Batch 36100/40000 (90.2%) - Train Loss: 1.7101, Val Loss: 1.7224
# Batch 36150/40000 (90.4%) - Train Loss: 1.7355, Val Loss: 1.7217
# Batch 36200/40000 (90.5%) - Train Loss: 1.6951, Val Loss: 1.7224
# Batch 36250/40000 (90.6%) - Train Loss: 1.7600, Val Loss: 1.7197
# Batch 36300/40000 (90.8%) - Train Loss: 1.7042, Val Loss: 1.7228
# Batch 36350/40000 (90.9%) - Train Loss: 1.7314, Val Loss: 1.7228
# Batch 36400/40000 (91.0%) - Train Loss: 1.7409, Val Loss: 1.7208
# Batch 36450/40000 (91.1%) - Train Loss: 1.6962, Val Loss: 1.7241
# Batch 36500/40000 (91.2%) - Train Loss: 1.7230, Val Loss: 1.7200
# Batch 36550/40000 (91.4%) - Train Loss: 1.7658, Val Loss: 1.7215
# Batch 36600/40000 (91.5%) - Train Loss: 1.6611, Val Loss: 1.7210
# Batch 36650/40000 (91.6%) - Train Loss: 1.7457, Val Loss: 1.7208
# Batch 36700/40000 (91.8%) - Train Loss: 1.7314, Val Loss: 1.7215
# Batch 36750/40000 (91.9%) - Train Loss: 1.7107, Val Loss: 1.7210
# Batch 36800/40000 (92.0%) - Train Loss: 1.7426, Val Loss: 1.7221
# Batch 36850/40000 (92.1%) - Train Loss: 1.7749, Val Loss: 1.7204
# Batch 36900/40000 (92.2%) - Train Loss: 1.6857, Val Loss: 1.7195
# Batch 36950/40000 (92.4%) - Train Loss: 1.7249, Val Loss: 1.7192
# Batch 37000/40000 (92.5%) - Train Loss: 1.7484, Val Loss: 1.7199
# Batch 37050/40000 (92.6%) - Train Loss: 1.7983, Val Loss: 1.7211
# Batch 37100/40000 (92.8%) - Train Loss: 1.7168, Val Loss: 1.7208
# Batch 37150/40000 (92.9%) - Train Loss: 1.7423, Val Loss: 1.7220
# Batch 37200/40000 (93.0%) - Train Loss: 1.7295, Val Loss: 1.7197
# Batch 37250/40000 (93.1%) - Train Loss: 1.7485, Val Loss: 1.7219
# Batch 37300/40000 (93.2%) - Train Loss: 1.7896, Val Loss: 1.7203
# Batch 37350/40000 (93.4%) - Train Loss: 1.7605, Val Loss: 1.7190
# Batch 37400/40000 (93.5%) - Train Loss: 1.7488, Val Loss: 1.7202
# Batch 37450/40000 (93.6%) - Train Loss: 1.7486, Val Loss: 1.7182
# Batch 37500/40000 (93.8%) - Train Loss: 1.7240, Val Loss: 1.7181
# Batch 37550/40000 (93.9%) - Train Loss: 1.7200, Val Loss: 1.7196
# Batch 37600/40000 (94.0%) - Train Loss: 1.7218, Val Loss: 1.7180
# Batch 37650/40000 (94.1%) - Train Loss: 1.7586, Val Loss: 1.7186
# Batch 37700/40000 (94.2%) - Train Loss: 1.7278, Val Loss: 1.7200
# Batch 37750/40000 (94.4%) - Train Loss: 1.6385, Val Loss: 1.7187
# Batch 37800/40000 (94.5%) - Train Loss: 1.6946, Val Loss: 1.7184
# Batch 37850/40000 (94.6%) - Train Loss: 1.7731, Val Loss: 1.7176
# Batch 37900/40000 (94.8%) - Train Loss: 1.7151, Val Loss: 1.7177
# Batch 37950/40000 (94.9%) - Train Loss: 1.6999, Val Loss: 1.7181
# Batch 38000/40000 (95.0%) - Train Loss: 1.6885, Val Loss: 1.7188
# Batch 38050/40000 (95.1%) - Train Loss: 1.6922, Val Loss: 1.7171
# Batch 38100/40000 (95.2%) - Train Loss: 1.6744, Val Loss: 1.7167
# Batch 38150/40000 (95.4%) - Train Loss: 1.7147, Val Loss: 1.7141
# Batch 38200/40000 (95.5%) - Train Loss: 1.7524, Val Loss: 1.7179
# Batch 38250/40000 (95.6%) - Train Loss: 1.6917, Val Loss: 1.7167
# Batch 38300/40000 (95.8%) - Train Loss: 1.7014, Val Loss: 1.7166
# Batch 38350/40000 (95.9%) - Train Loss: 1.6902, Val Loss: 1.7161
# Batch 38400/40000 (96.0%) - Train Loss: 1.7951, Val Loss: 1.7173
# Batch 38450/40000 (96.1%) - Train Loss: 1.8053, Val Loss: 1.7170
# Batch 38500/40000 (96.2%) - Train Loss: 1.6652, Val Loss: 1.7180
# Batch 38550/40000 (96.4%) - Train Loss: 1.7237, Val Loss: 1.7161
# Batch 38600/40000 (96.5%) - Train Loss: 1.6744, Val Loss: 1.7162
# Batch 38650/40000 (96.6%) - Train Loss: 1.6734, Val Loss: 1.7156
# Batch 38700/40000 (96.8%) - Train Loss: 1.6767, Val Loss: 1.7153
# Batch 38750/40000 (96.9%) - Train Loss: 1.7520, Val Loss: 1.7143
# Batch 38800/40000 (97.0%) - Train Loss: 1.7387, Val Loss: 1.7148
# Batch 38850/40000 (97.1%) - Train Loss: 1.7207, Val Loss: 1.7148
# Batch 38900/40000 (97.2%) - Train Loss: 1.7473, Val Loss: 1.7157
# Batch 38950/40000 (97.4%) - Train Loss: 1.6830, Val Loss: 1.7148
# Batch 39000/40000 (97.5%) - Train Loss: 1.8114, Val Loss: 1.7152
# Batch 39050/40000 (97.6%) - Train Loss: 1.7279, Val Loss: 1.7133
# Batch 39100/40000 (97.8%) - Train Loss: 1.7430, Val Loss: 1.7161
# Batch 39150/40000 (97.9%) - Train Loss: 1.7137, Val Loss: 1.7152
# Batch 39200/40000 (98.0%) - Train Loss: 1.6999, Val Loss: 1.7132
# Batch 39250/40000 (98.1%) - Train Loss: 1.6939, Val Loss: 1.7172
# Batch 39300/40000 (98.2%) - Train Loss: 1.7331, Val Loss: 1.7148
# Batch 39350/40000 (98.4%) - Train Loss: 1.6819, Val Loss: 1.7142
# Batch 39400/40000 (98.5%) - Train Loss: 1.7160, Val Loss: 1.7142
# Batch 39450/40000 (98.6%) - Train Loss: 1.7884, Val Loss: 1.7128
# Batch 39500/40000 (98.8%) - Train Loss: 1.7267, Val Loss: 1.7152
# Batch 39550/40000 (98.9%) - Train Loss: 1.6962, Val Loss: 1.7139
# Batch 39600/40000 (99.0%) - Train Loss: 1.7685, Val Loss: 1.7147
# Batch 39650/40000 (99.1%) - Train Loss: 1.6826, Val Loss: 1.7165
# Batch 39700/40000 (99.2%) - Train Loss: 1.6354, Val Loss: 1.7163
# Batch 39750/40000 (99.4%) - Train Loss: 1.7359, Val Loss: 1.7132
# Batch 39800/40000 (99.5%) - Train Loss: 1.6610, Val Loss: 1.7141
# Batch 39850/40000 (99.6%) - Train Loss: 1.7470, Val Loss: 1.7128
# Batch 39900/40000 (99.8%) - Train Loss: 1.6654, Val Loss: 1.7136
# Batch 39950/40000 (99.9%) - Train Loss: 1.6994, Val Loss: 1.7130
#
# ===== Training Complete =====
# Final train loss: 1.7084
# Final validation loss: 1.7130
# Final test loss: 1.7402

# %%
plt.figure(figsize=(18,10))
plt.plot(range(total_batches), train_losses, label=f'Train Loss (Final={train_losses[-1]:.4f})', color='blue')
plt.plot(val_batch_indices, val_losses, label=f'Val Loss (Final={val_losses[-1]:.4f})', color='red')
plt.title('Training and Validation Loss')
plt.ylabel('Loss (log Scale)')
plt.xlabel('Batch')
plt.yscale('log')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Model generations

# %%
def generate_sequence(prompt_text, max_length=100):
    # Ensure the prompt is at least context_size characters
    if len(prompt_text) < context_size:
        print(f"Warning: Prompt must be at least {context_size} characters. Padding with spaces.")
        prompt_text = ' ' * (context_size - len(prompt_text)) + prompt_text
    
    context = prompt_text[-context_size:]
    output = [char for char in context]
    
    context_indices = [char_to_idx[char] for char in context]
    
    with torch.no_grad():
        for _ in range(max_length):
            x = torch.tensor([context_indices], device=device)
            
            x_embed = embed[x]
            hidden_act = F.relu(x_embed.view(-1, context_size * model_dim) @ hidden_ctx)
            for layer in range(hidden.shape[0]):
                hidden_act = F.relu(hidden_act @ hidden[layer])
            logits = hidden_act @ out
            
            probs = F.softmax(logits, dim=-1)
            
            # Sample next character
            next_idx = torch.multinomial(probs[0], 1).item()
            next_char = idx_to_char[next_idx]
            
            if next_char == '<EOS>':
                break
                
            output.append(next_char)
            
            # Update context (slide the window)
            context_indices = context_indices[1:] + [next_idx]
            
        return ''.join(output)

print("Starting with 'The ':")
print(generate_sequence('The day that he', max_length=200))

print("\nStarting with 'In a blue field ':")
print(generate_sequence('In a blue field ', max_length=200))

print("\nStarting with 'She thought about':")
print(generate_sequence('She thought about ', max_length=200))
# Out:
# Starting with 'The ':
# The day that head it farder on a treaky Berdida pran in the heach by Mader , Chamages Turders mifher firted the Plook Connermedatrolo berselled the first of the drounding to playancis . Which has currieting the sevb
#
# Starting with 'In a blue field ':
# n a blue field a stilas . Helon with taxbization , for the centures . Ot the differenley in the Union .
#  Or Hie has stant a five number = =
#
#  Thren as other at threationalish was showlelft vicies area to have res
#
# Starting with 'She thought about':
#  thought about sincestium of which of accowing the Hintancery infach ; 劇oin a lead a stono also a milling new mility aroupamily performance first : the Correct and a sen released that the Bosbingless , and that rece

# %% [markdown]
# This is surprisingly close to coherent words and even grammar.

# %% [markdown]
# ## Not the full picture
#
# While smart parameter initializations give us a very good head start in training stability and reliability they **do NOT** guarantee that such properties will be preserved as training progresses. Training the model of course changes it's parameters and we should not assume that we have any reason to expect that all those nice statistical properties we initialized them with will stay as they are when the model starts to fit our data, which may (and often does) end up causing the same issues that we were trying to solve here (dead neurons, unstable training), we've just kicked it further down the line.
#
# We can demonstrate this by extracting the layer pre-activations on a forward pass on the trained model and anayzing their statistical properties.

# %%
import seaborn as sns

sample_size = 1024
test_indices = torch.randperm(len(X_test))[:sample_size]
x_sample = X_test[test_indices]

def analyze_activations(model_params, x_data, num_layers=model_depth):
    embed, hidden_ctx, hidden, out = model_params
    batch_size = x_data.shape[0]
    
    layer_stats = []
    
    with torch.no_grad():
        x_embed = embed[x_data]
        pre_act = x_embed.view(-1, context_size * model_dim) @ hidden_ctx
        
        pre_act_np = pre_act.cpu().numpy()
        stats = {
            'layer': 0,
            'mean': float(np.mean(pre_act_np)),
            'variance': float(np.var(pre_act_np)),
            'min': float(np.min(pre_act_np)),
            'max': float(np.max(pre_act_np)),
            'negative_pct': float(np.mean(pre_act_np < 0) * 100),
            'histogram': pre_act_np.flatten()
        }
        layer_stats.append(stats)
        
        hidden_act = F.relu(pre_act)
        
        for layer in range(hidden.shape[0]):
            pre_act = hidden_act @ hidden[layer]
            
            pre_act_np = pre_act.cpu().numpy()
            stats = {
                'layer': layer + 1,
                'mean': float(np.mean(pre_act_np)),
                'variance': float(np.var(pre_act_np)),
                'min': float(np.min(pre_act_np)),
                'max': float(np.max(pre_act_np)),
                'negative_pct': float(np.mean(pre_act_np < 0) * 100),
                'histogram': pre_act_np.flatten()
            }
            layer_stats.append(stats)
            
            hidden_act = F.relu(pre_act)
    
    return layer_stats

layer_stats = analyze_activations([embed, hidden_ctx, hidden, out], x_sample)

plt.figure(figsize=(15, 10))

# Plot 1: Mean and variance across layers
plt.subplot(2, 2, 1)
plt.plot([s['layer'] for s in layer_stats], [s['mean'] for s in layer_stats], 'b-', label='Mean')
plt.axhline(y=0, color='r', linestyle='--', alpha=0.5)
plt.xlabel('Layer')
plt.ylabel('Mean Pre-activation')
plt.title('Mean Pre-activation Values Across Layers')
plt.grid(True, alpha=0.3)
plt.legend()

# Plot 2: Variance across layers
plt.subplot(2, 2, 2)
plt.plot([s['layer'] for s in layer_stats], [s['variance'] for s in layer_stats], 'g-')
plt.xlabel('Layer')
plt.ylabel('Variance')
plt.title('Pre-activation Variance Across Layers')
plt.grid(True, alpha=0.3)

# Plot 3: Percentage of negative pre-activations (dying ReLUs)
plt.subplot(2, 2, 3)
plt.plot([s['layer'] for s in layer_stats], [s['negative_pct'] for s in layer_stats], color='purple', alpha=0.7)
plt.axhline(y=50, color='r', linestyle='--', alpha=0.5)
plt.xlabel('Layer')
plt.ylabel('% Negative Values')
plt.title('Percentage of Negative Pre-activations (Potential Dying ReLUs)')
plt.grid(True, axis='y', alpha=0.3)

# Plot 4: Min/Max range across layers
plt.subplot(2, 2, 4)
plt.plot([s['layer'] for s in layer_stats], [s['min'] for s in layer_stats], 'r-', label='Min')
plt.plot([s['layer'] for s in layer_stats], [s['max'] for s in layer_stats], 'b-', label='Max')
plt.xlabel('Layer')
plt.ylabel('Value')
plt.title('Min/Max Pre-activation Range Across Layers')
plt.grid(True, alpha=0.3)
plt.legend()

plt.tight_layout()
plt.show()

selected_layers = [0, 9, 19, 29]  # First, middle, and last layers
plt.figure(figsize=(16, 12))

for i, layer_idx in enumerate(selected_layers):
    plt.subplot(2, 2, i+1)
    
    hist_data = layer_stats[layer_idx]['histogram']
    
    sns.histplot(hist_data, bins=40, kde=True)
    plt.axvline(x=0, color='r', linestyle='--', alpha=0.7)
    plt.title(f'Layer {layer_idx} Pre-activation Distribution')
    plt.xlabel('Pre-activation Value')
    plt.ylabel('Frequency')
    
    neg_pct = layer_stats[layer_idx]['negative_pct']
    plt.annotate(f'{neg_pct:.1f}% Negative', xy=(0.05, 0.9), xycoords='axes fraction')

plt.tight_layout()
plt.show()

# %% [markdown]
# As we can observe our layer stats are all messed up, so many things are wrong here despite being careful with our initialization statistics for the purpose of preventing exactly the problems we're observing.
#
# The variance is absurd, to the point that it's surprising the model is learning anything at all. We're already way beyond the realm of nice (or even single digit) variances by layer 2 or 3 and it only gets worse from there. Massive variances create massive activations, if the variances where at least consistent the only problem we would have is numerical stability during training but this is not the case. On top of that we havve to deal with wildly different gradient norms per layer, which means that the layers with higher variance will become dominant and effectively render earlier layers dead.
#
# We can also see that ReLU preactivations are trending negative, which is another problem on it's own. This is ReLU's version of saturation and it means that a significant portion of the error signal is just getting cut off somewhere on the way back, since ReLU zeroes out negative numbers having mostly negative pre-activations means we're losing a lot of information.
#
# So, we're not clear of the variance problem just yet.
